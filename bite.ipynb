# %% [markdown]
# <h1> Recherche </h1>

# %%
from moviepy.video.io.ffmpeg_tools import ffmpeg_extract_subclip
from moviepy.editor import VideoFileClip

def reshape_clip(name,num):
    clip = VideoFileClip(name)
    clip=clip.resize((360,360))
    clip.write_videofile(name.replace("#.mp4","@#.mp4"))
    print(clip.duration,"secondes")
    durée=clip.duration
    echelon=durée/num
    del clip
    for i in range(num):
        start_time,end_time=i*echelon,(i+1)*echelon
        ffmpeg_extract_subclip(name.replace("#.mp4","@#.mp4"), start_time, end_time, targetname=name.replace("#.mp4","{}.mp4".format(i)))
    return True
val=12
reshape_clip("./video/fache/fache#.mp4",val)
reshape_clip("./video/fache/maxou_fache#.mp4",val)
reshape_clip("./video/fache/antoju_fache#.mp4",val)
#reshape_clip("./video/fache/s_fache#.mp4",8)
reshape_clip("./video/heureux/heureux#.mp4",val)
reshape_clip("./video/heureux/maxou_heureux#.mp4",val)
#reshape_clip("./video/heureux/sound_heureux#.mp4",val)
reshape_clip("./video/heureux/antoine_heureux#.mp4",val)
reshape_clip("./video/heureux/antoine2_heureux#.mp4",val)
reshape_clip("./video/heureux/antoju_heureux#.mp4",val)
reshape_clip("./video/triste/triste#.mp4",val)
reshape_clip("./video/triste/antoine_triste#.mp4",val)
reshape_clip("./video/triste/maxou_triste#.mp4",val)
reshape_clip("./video/deg/deg#.mp4",val)
reshape_clip("./video/deg/antoine_deg#.mp4",val)
#reshape_clip("./video/deg/sound_deg#.mp4",val)
# Out:
# chunk:   0%|                                                                         | 0/306 [00:00<?, ?it/s, now=None]
# Moviepy - Building video ./video/fache/fache@#.mp4.
# MoviePy - Writing audio in fache@#TEMP_MPY_wvf_snd.mp3
# t:   0%|                                                                             | 0/107 [00:00<?, ?it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video ./video/fache/fache@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/fache/fache@#.mp4
# 13.84 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# chunk:   0%|                                                                         | 0/280 [00:00<?, ?it/s, now=None]
# Moviepy - Building video ./video/fache/maxou_fache@#.mp4.
# MoviePy - Writing audio in maxou_fache@#TEMP_MPY_wvf_snd.mp3
# t:   0%|                                                                              | 0/98 [00:00<?, ?it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video ./video/fache/maxou_fache@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/fache/maxou_fache@#.mp4
# 12.67 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# chunk:   0%|                                                                         | 0/411 [00:00<?, ?it/s, now=None]
# Moviepy - Building video ./video/fache/antoju_fache@#.mp4.
# MoviePy - Writing audio in antoju_fache@#TEMP_MPY_wvf_snd.mp3
# t:   0%|                                                                             | 0/540 [00:00<?, ?it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video ./video/fache/antoju_fache@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/fache/antoju_fache@#.mp4
# 18.6 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# chunk:   0%|                                                                         | 0/254 [00:00<?, ?it/s, now=None]
# Moviepy - Building video ./video/heureux/heureux@#.mp4.
# MoviePy - Writing audio in heureux@#TEMP_MPY_wvf_snd.mp3
# t:   0%|                                                                              | 0/89 [00:00<?, ?it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video ./video/heureux/heureux@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/heureux/heureux@#.mp4
# 11.49 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# chunk:   0%|                                                                         | 0/332 [00:00<?, ?it/s, now=None]
# Moviepy - Building video ./video/heureux/maxou_heureux@#.mp4.
# MoviePy - Writing audio in maxou_heureux@#TEMP_MPY_wvf_snd.mp3
# t:   0%|                                                                             | 0/116 [00:00<?, ?it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video ./video/heureux/maxou_heureux@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/heureux/maxou_heureux@#.mp4
# 15.03 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# chunk:   0%|                                                                         | 0/227 [00:00<?, ?it/s, now=None]
# Moviepy - Building video ./video/heureux/sound_heureux@#.mp4.
# MoviePy - Writing audio in sound_heureux@#TEMP_MPY_wvf_snd.mp3
# t:   0%|                                                                             | 0/299 [00:00<?, ?it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video ./video/heureux/sound_heureux@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/heureux/sound_heureux@#.mp4
# 10.28 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# chunk:   0%|                                                                         | 0/396 [00:00<?, ?it/s, now=None]
# Moviepy - Building video ./video/heureux/antoine_heureux@#.mp4.
# MoviePy - Writing audio in antoine_heureux@#TEMP_MPY_wvf_snd.mp3
# t:   0%|                                                                             | 0/520 [00:00<?, ?it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video ./video/heureux/antoine_heureux@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/heureux/antoine_heureux@#.mp4
# 17.93 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# chunk:   0%|                                                                         | 0/356 [00:00<?, ?it/s, now=None]
# Moviepy - Building video ./video/heureux/antoine2_heureux@#.mp4.
# MoviePy - Writing audio in antoine2_heureux@#TEMP_MPY_wvf_snd.mp3
# t:   0%|                                                                             | 0/469 [00:00<?, ?it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video ./video/heureux/antoine2_heureux@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/heureux/antoine2_heureux@#.mp4
# 16.14 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# chunk:   0%|                                                                         | 0/352 [00:00<?, ?it/s, now=None]
# Moviepy - Building video ./video/heureux/antoju_heureux@#.mp4.
# MoviePy - Writing audio in antoju_heureux@#TEMP_MPY_wvf_snd.mp3
# t:   0%|                                                                             | 0/462 [00:00<?, ?it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video ./video/heureux/antoju_heureux@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/heureux/antoju_heureux@#.mp4
# 15.93 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# chunk:   0%|                                                                         | 0/286 [00:00<?, ?it/s, now=None]
# Moviepy - Building video ./video/triste/triste@#.mp4.
# MoviePy - Writing audio in triste@#TEMP_MPY_wvf_snd.mp3
# t:   0%|                                                                             | 0/100 [00:00<?, ?it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video ./video/triste/triste@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/triste/triste@#.mp4
# 12.93 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# chunk:   0%|                                                                         | 0/384 [00:00<?, ?it/s, now=None]
# Moviepy - Building video ./video/triste/antoine_triste@#.mp4.
# MoviePy - Writing audio in antoine_triste@#TEMP_MPY_wvf_snd.mp3
# t:   0%|                                                                             | 0/504 [00:00<?, ?it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video ./video/triste/antoine_triste@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/triste/antoine_triste@#.mp4
# 17.37 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# chunk:   0%|                                                                         | 0/289 [00:00<?, ?it/s, now=None]
# Moviepy - Building video ./video/triste/maxou_triste@#.mp4.
# MoviePy - Writing audio in maxou_triste@#TEMP_MPY_wvf_snd.mp3
# t:   0%|                                                                             | 0/101 [00:00<?, ?it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video ./video/triste/maxou_triste@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/triste/maxou_triste@#.mp4
# 13.07 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# chunk:   0%|                                                                         | 0/277 [00:00<?, ?it/s, now=None]
# Moviepy - Building video ./video/deg/deg@#.mp4.
# MoviePy - Writing audio in deg@#TEMP_MPY_wvf_snd.mp3
# t:   0%|                                                                              | 0/97 [00:00<?, ?it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video ./video/deg/deg@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/deg/deg@#.mp4
# 12.55 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# chunk:   0%|                                                                         | 0/371 [00:00<?, ?it/s, now=None]
# Moviepy - Building video ./video/deg/antoine_deg@#.mp4.
# MoviePy - Writing audio in antoine_deg@#TEMP_MPY_wvf_snd.mp3
# t:   0%|                                                                             | 0/488 [00:00<?, ?it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video ./video/deg/antoine_deg@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/deg/antoine_deg@#.mp4
# 16.81 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# True

# %%
import os
import glob
import keras
from keras_video import VideoFrameGenerator
# use sub directories names as classes
classes = [i.split(os.path.sep)[1] for i in glob.glob('./video/*') if "#" not in i]
classes.sort()
# some global params
SIZE = (112, 112)
CHANNELS = 3
NBFRAME = 5
BS = 8
# pattern to get videos and classes
glob_pattern='./video/{classname}/*.mp4'
# for data augmentation
data_aug = keras.preprocessing.image.ImageDataGenerator(
    zoom_range=.1,
    horizontal_flip=True,
    rotation_range=8,
    width_shift_range=.2,
    height_shift_range=.2)
# Create video frame generator
train = VideoFrameGenerator(
    classes=classes, 
    glob_pattern=glob_pattern,
    nb_frames=NBFRAME,
    split=.33, 
    shuffle=True,
    batch_size=BS,
    target_shape=SIZE,
    nb_channel=CHANNELS,
    transformation=data_aug,
    use_frame_cache=True)
# Out:
# Warning, `split` argument is replaced by `split_val`, please condider to change your source code.The `split` argument will be removed in future releases.
# class deg, validation count: 9, train count: 20
# class fache, validation count: 13, train count: 29
# class heureux, validation count: 27, train count: 57
# class triste, validation count: 13, train count: 29
# Total data: 4 classes for 135 files for train

# %%
valid = train.get_validation_generator()
# Out:
# Total data: 4 classes for 62 files for validation

# %%
import keras_video.utils
keras_video.utils.show_sample(train)

# %%
from keras.layers import Conv2D, BatchNormalization, \
    MaxPool2D, GlobalMaxPool2D
def build_convnet(shape=(112, 112, 3)):
    momentum = .9
    model = keras.Sequential()
    model.add(Conv2D(64, (3,3), input_shape=shape,
        padding='same', activation='relu'))
    model.add(Conv2D(64, (3,3), padding='same', activation='relu'))
    model.add(BatchNormalization(momentum=momentum))
    
    model.add(MaxPool2D())
    
    model.add(Conv2D(128, (3,3), padding='same', activation='relu'))
    model.add(Conv2D(128, (3,3), padding='same', activation='relu'))
    model.add(BatchNormalization(momentum=momentum))
    
    model.add(MaxPool2D())
    
    model.add(Conv2D(256, (3,3), padding='same', activation='relu'))
    model.add(Conv2D(256, (3,3), padding='same', activation='relu'))
    model.add(BatchNormalization(momentum=momentum))
    
    model.add(MaxPool2D())
    
    model.add(Conv2D(512, (3,3), padding='same', activation='relu'))
    model.add(Conv2D(512, (3,3), padding='same', activation='relu'))
    model.add(BatchNormalization(momentum=momentum))
    
    # flatten...
    model.add(GlobalMaxPool2D())
    return model

# %%
from keras.layers import TimeDistributed, GRU, Dense, Dropout
def action_model(shape=(5, 112, 112, 3), nbout=3):
    # Create our convnet with (112, 112, 3) input shape
    convnet = build_convnet(shape[1:])
    
    # then create our final model
    model = keras.Sequential()
    # add the convnet with (5, 112, 112, 3) shape
    model.add(TimeDistributed(convnet, input_shape=shape))
    # here, you can also use GRU or LSTM
    model.add(GRU(64,dropout=0.2))
    # and finally, we make a decision network
    model.add(Dense(1024, activation='relu'))
    model.add(Dropout(.5))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(.5))
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(.5))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(nbout, activation='softmax'))
    return model

# %%
INSHAPE=(NBFRAME,) + SIZE + (CHANNELS,) # (5, 112, 112, 3)
model = action_model(INSHAPE, len(classes))
optimizer = keras.optimizers.Adam(0.001)
model.compile(
    optimizer,
    'categorical_crossentropy',
    metrics=['acc']
)

# %%
EPOCHS=50
# create a "chkp" directory before to run that
# because ModelCheckpoint will write models inside
callbacks = [
    keras.callbacks.ReduceLROnPlateau(verbose=1),
    keras.callbacks.ModelCheckpoint(
        './../chkp/weights.{epoch:02d}-{loss:.2f}.hdf5',
        verbose=1),
]
history=model.fit_generator(
    train,
    validation_data=valid,
    verbose=1,
    epochs=EPOCHS,
    callbacks=callbacks
)
# Out:
# Epoch 1/2
# 13/16 [=======================>......] - ETA: 21s - loss: 1.3818 - acc: 0.3462
# ---------------------------------------------------------------------------
# UnknownError                              Traceback (most recent call last)
# <ipython-input-30-b84cf9dd1fef> in <module>
#      13     verbose=1,
#      14     epochs=EPOCHS,
# ---> 15     callbacks=callbacks
#      16 )
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\util\deprecation.py in new_func(*args, **kwargs)
#     322               'in a future version' if date is None else ('after %s' % date),
#     323               instructions)
# --> 324       return func(*args, **kwargs)
#     325     return tf_decorator.make_decorator(
#     326         func, new_func, 'deprecated',
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1827         use_multiprocessing=use_multiprocessing,
#    1828         shuffle=shuffle,
# -> 1829         initial_epoch=initial_epoch)
#    1830
#    1831   @deprecation.deprecated(
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\keras\engine\training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1096                 batch_size=batch_size):
#    1097               callbacks.on_train_batch_begin(step)
# -> 1098               tmp_logs = train_function(iterator)
#    1099               if data_handler.should_sync:
#    1100                 context.async_wait()
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     805       # In this case we have created variables on the first call, so we run the
#     806       # defunned version which is guaranteed to never create variables.
# --> 807       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     808     elif self._stateful_fn is not None:
#     809       # Release the lock early so that multiple threads can perform the call
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2827     with self._lock:
#    2828       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2829     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2830
#    2831   @property
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\eager\function.py in _filtered_call(self, args, kwargs, cancellation_manager)
#    1846                            resource_variable_ops.BaseResourceVariable))],
#    1847         captured_inputs=self.captured_inputs,
# -> 1848         cancellation_manager=cancellation_manager)
#    1849
#    1850   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1922       # No tape is watching; skip to running the function.
#    1923       return self._build_call_outputs(self._inference_function.call(
# -> 1924           ctx, args, cancellation_manager=cancellation_manager))
#    1925     forward_backward = self._select_forward_and_backward_functions(
#    1926         args,
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     548               inputs=args,
#     549               attrs=attrs,
# --> 550               ctx=ctx)
#     551         else:
#     552           outputs = execute.execute_with_cancellation(
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# UnknownError:  IndexError: list index out of range
# Traceback (most recent call last):
#
#   File "C:\Users\minim\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\ops\script_ops.py", line 244, in __call__
#     ret = func(*args)
#
#   File "C:\Users\minim\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\autograph\impl\api.py", line 302, in wrapper
#     return func(*args, **kwargs)
#
#   File "C:\Users\minim\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\data\ops\dataset_ops.py", line 827, in generator_py_func
#     values = next(generator_state.get_iterator(iterator_id))
#
#   File "C:\Users\minim\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\keras\engine\data_adapter.py", line 814, in wrapped_generator
#     for data in generator_fn():
#
#   File "C:\Users\minim\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\keras\engine\data_adapter.py", line 940, in generator_fn
#     yield x[i]
#
#   File "C:\Users\minim\Anaconda3\envs\python37\lib\site-packages\keras_video\generator.py", line 332, in __getitem__
#     classname = self._get_classname(video)
#
#   File "C:\Users\minim\Anaconda3\envs\python37\lib\site-packages\keras_video\generator.py", line 383, in _get_classname
#     classname = re.findall(pattern, video)[0]
#
# IndexError: list index out of range
#
#
# 	 [[{{node PyFunc}}]]
# 	 [[IteratorGetNext]] [Op:__inference_train_function_23073]
#
# Function call stack:
# train_function

# %%
history.history['acc']

# %%
history.history['val_acc']

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.show()
