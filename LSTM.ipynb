# %% [markdown]
# <h1> Recherche </h1>

# %%
from moviepy.video.io.ffmpeg_tools import ffmpeg_extract_subclip
from moviepy.editor import VideoFileClip

def reshape_clip(name,num):
    clip = VideoFileClip(name)
    clip=clip.resize((360,360))
    clip.write_videofile(name.replace("#.mp4","@#.mp4"))
    print(clip.duration,"secondes")
    durée=clip.duration
    echelon=durée/num
    del clip
    for i in range(num):
        start_time,end_time=i*echelon,(i+1)*echelon
        ffmpeg_extract_subclip(name.replace("#.mp4","@#.mp4"), start_time, end_time, targetname=name.replace("#.mp4","{}.mp4".format(i)))
    return True
val=12
reshape_clip("./video/fache/fache#.mp4",val)
reshape_clip("./video/fache/maxou_fache#.mp4",val)
reshape_clip("./video/fache/antoju_fache#.mp4",val)
reshape_clip("./video/fache/theo_1#.mp4",val)
reshape_clip("./video/fache/theo_2#.mp4",val)
reshape_clip("./video/deg/theo_1#.mp4",val)
reshape_clip("./video/deg/theo_2#.mp4",val)
reshape_clip("./video/heureux/theo_1#.mp4",val)
#reshape_clip("./video/fache/s_fache#.mp4",8)
reshape_clip("./video/heureux/heureux#.mp4",val)
reshape_clip("./video/heureux/maxou_heureux#.mp4",val)
#
reshape_clip("./video/heureux/antoine_heureux#.mp4",val)
reshape_clip("./video/heureux/antoine2_heureux#.mp4",val)
reshape_clip("./video/heureux/antoju_heureux#.mp4",val)
reshape_clip("./video/triste/triste#.mp4",val)
reshape_clip("./video/triste/antoine_triste#.mp4",val)
reshape_clip("./video/triste/maxou_triste#.mp4",val)
reshape_clip("./video/deg/deg#.mp4",val)
reshape_clip("./video/deg/antoine_deg#.mp4",val)
reshape_clip("./video/deg/sound_deg#.mp4",val)
# Out:
# Moviepy - Building video ./video/fache/fache@#.mp4.
# MoviePy - Writing audio in fache@#TEMP_MPY_wvf_snd.mp3
# t:  14%|█▍        | 15/107 [00:00<00:00, 148.52it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video ./video/fache/fache@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/fache/fache@#.mp4
# 13.84 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# t:   0%|          | 0/98 [00:00<?, ?it/s, now=None]
# Moviepy - Building video ./video/fache/maxou_fache@#.mp4.
# MoviePy - Writing audio in maxou_fache@#TEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video ./video/fache/maxou_fache@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/fache/maxou_fache@#.mp4
# 12.67 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# chunk:  20%|█▉        | 81/411 [00:00<00:00, 810.00it/s, now=None]
# Moviepy - Building video ./video/fache/antoju_fache@#.mp4.
# MoviePy - Writing audio in antoju_fache@#TEMP_MPY_wvf_snd.mp3
# t:   3%|▎         | 16/540 [00:00<00:07, 67.10it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video ./video/fache/antoju_fache@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/fache/antoju_fache@#.mp4
# 18.6 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# t:   6%|▌         | 6/97 [00:00<00:01, 59.41it/s, now=None]
# Moviepy - Building video ./video/fache/theo_1@#.mp4.
# Moviepy - Writing video ./video/fache/theo_1@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/fache/theo_1@#.mp4
# 5.79 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# t:   6%|▋         | 7/110 [00:00<00:01, 69.97it/s, now=None]
# Moviepy - Building video ./video/fache/theo_2@#.mp4.
# Moviepy - Writing video ./video/fache/theo_2@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/fache/theo_2@#.mp4
# 6.56 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# t:   6%|▌         | 7/117 [00:00<00:01, 65.43it/s, now=None]
# Moviepy - Building video ./video/deg/theo_1@#.mp4.
# Moviepy - Writing video ./video/deg/theo_1@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/deg/theo_1@#.mp4
# 6.99 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# t:   6%|▌         | 7/115 [00:00<00:01, 66.64it/s, now=None]
# Moviepy - Building video ./video/deg/theo_2@#.mp4.
# Moviepy - Writing video ./video/deg/theo_2@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/deg/theo_2@#.mp4
# 6.87 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# t:   4%|▍         | 7/167 [00:00<00:02, 66.67it/s, now=None]
# Moviepy - Building video ./video/heureux/theo_1@#.mp4.
# Moviepy - Writing video ./video/heureux/theo_1@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/heureux/theo_1@#.mp4
# 10.0 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# t:   0%|          | 0/89 [00:00<?, ?it/s, now=None]
# Moviepy - Building video ./video/heureux/heureux@#.mp4.
# MoviePy - Writing audio in heureux@#TEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video ./video/heureux/heureux@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/heureux/heureux@#.mp4
# 11.49 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Building video ./video/heureux/maxou_heureux@#.mp4.
# MoviePy - Writing audio in maxou_heureux@#TEMP_MPY_wvf_snd.mp3
# t:  14%|█▍        | 16/116 [00:00<00:00, 155.27it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video ./video/heureux/maxou_heureux@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/heureux/maxou_heureux@#.mp4
# 15.03 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# chunk:  24%|██▍       | 96/396 [00:00<00:00, 959.91it/s, now=None]
# Moviepy - Building video ./video/heureux/antoine_heureux@#.mp4.
# MoviePy - Writing audio in antoine_heureux@#TEMP_MPY_wvf_snd.mp3
# t:   1%|▏         | 7/520 [00:00<00:07, 67.96it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video ./video/heureux/antoine_heureux@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/heureux/antoine_heureux@#.mp4
# 17.93 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# chunk:  26%|██▌       | 93/356 [00:00<00:00, 921.19it/s, now=None]
# Moviepy - Building video ./video/heureux/antoine2_heureux@#.mp4.
# MoviePy - Writing audio in antoine2_heureux@#TEMP_MPY_wvf_snd.mp3
# t:   1%|▏         | 7/469 [00:00<00:06, 67.96it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video ./video/heureux/antoine2_heureux@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/heureux/antoine2_heureux@#.mp4
# 16.14 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# chunk:  27%|██▋       | 94/352 [00:00<00:00, 931.12it/s, now=None]
# Moviepy - Building video ./video/heureux/antoju_heureux@#.mp4.
# MoviePy - Writing audio in antoju_heureux@#TEMP_MPY_wvf_snd.mp3
# t:   2%|▏         | 7/462 [00:00<00:06, 69.97it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video ./video/heureux/antoju_heureux@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/heureux/antoju_heureux@#.mp4
# 15.93 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Building video ./video/triste/triste@#.mp4.
# MoviePy - Writing audio in triste@#TEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video ./video/triste/triste@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/triste/triste@#.mp4
# 12.93 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# chunk:  24%|██▍       | 93/384 [00:00<00:00, 930.00it/s, now=None]
# Moviepy - Building video ./video/triste/antoine_triste@#.mp4.
# MoviePy - Writing audio in antoine_triste@#TEMP_MPY_wvf_snd.mp3
# t:   1%|▏         | 7/504 [00:00<00:07, 67.28it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video ./video/triste/antoine_triste@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/triste/antoine_triste@#.mp4
# 17.37 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# t:   0%|          | 0/101 [00:00<?, ?it/s, now=None]
# Moviepy - Building video ./video/triste/maxou_triste@#.mp4.
# MoviePy - Writing audio in maxou_triste@#TEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video ./video/triste/maxou_triste@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/triste/maxou_triste@#.mp4
# 13.07 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# t:   0%|          | 0/97 [00:00<?, ?it/s, now=None]
# Moviepy - Building video ./video/deg/deg@#.mp4.
# MoviePy - Writing audio in deg@#TEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video ./video/deg/deg@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/deg/deg@#.mp4
# 12.55 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# chunk:  25%|██▍       | 92/371 [00:00<00:00, 910.49it/s, now=None]
# Moviepy - Building video ./video/deg/antoine_deg@#.mp4.
# MoviePy - Writing audio in antoine_deg@#TEMP_MPY_wvf_snd.mp3
# t:   1%|▏         | 7/488 [00:00<00:07, 68.67it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video ./video/deg/antoine_deg@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/deg/antoine_deg@#.mp4
# 16.81 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# chunk:  29%|██▉       | 66/226 [00:00<00:00, 655.65it/s, now=None]
# Moviepy - Building video ./video/deg/sound_deg@#.mp4.
# MoviePy - Writing audio in sound_deg@#TEMP_MPY_wvf_snd.mp3
# t:   2%|▏         | 5/297 [00:00<00:06, 47.17it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video ./video/deg/sound_deg@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/deg/sound_deg@#.mp4
# 10.22 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# True

# %%
reshape_clip("./video/deg/sound_deg#.mp4",val)
#reshape_clip("./video/heureux/sound_heureux#.mp4",val)
# Out:
# Moviepy - Building video ./video/deg/sound_deg@#.mp4.
# MoviePy - Writing audio in sound_deg@#TEMP_MPY_wvf_snd.mp3
# t:   4%|▎         | 11/297 [00:00<00:02, 109.99it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video ./video/deg/sound_deg@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/deg/sound_deg@#.mp4
# 10.22 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# True

# %%
import os
import glob
import keras
from keras_video import VideoFrameGenerator
# use sub directories names as classes
classes = [i.split(os.path.sep)[1] for i in glob.glob('./video/*') if "#" not in i]
classes.sort()
# some global params
SIZE = (112, 112)
CHANNELS = 3
NBFRAME = 5
BS = 8
# pattern to get videos and classes
glob_pattern='./video/{classname}/*.mp4'
# for data augmentation
data_aug = keras.preprocessing.image.ImageDataGenerator(
    zoom_range=.1,
    horizontal_flip=True,
    rotation_range=8,
    width_shift_range=.2,
    height_shift_range=.2)
# Create video frame generator
train = VideoFrameGenerator(
    classes=classes, 
    glob_pattern=glob_pattern,
    nb_frames=NBFRAME,
    split=.33, 
    shuffle=True,
    batch_size=BS,
    target_shape=SIZE,
    nb_channel=CHANNELS,
    transformation=data_aug,
    use_frame_cache=True)
# Out:
# Warning, `split` argument is replaced by `split_val`, please condider to change your source code.The `split` argument will be removed in future releases.
# class deg, validation count: 23, train count: 47
# class fache, validation count: 23, train count: 47
# class heureux, validation count: 27, train count: 57
# class triste, validation count: 13, train count: 29
# Total data: 4 classes for 180 files for train

# %%
valid = train.get_validation_generator()
# Out:
# Total data: 4 classes for 86 files for validation

# %%
import keras_video.utils
keras_video.utils.show_sample(train)

# %%
from keras.layers import Conv2D, BatchNormalization, \
    MaxPool2D, GlobalMaxPool2D, LSTM
def build_convnet(shape=(112, 112, 3)):
    momentum = .9
    model = keras.Sequential()
    model.add(Conv2D(64, (3,3), input_shape=shape,
        padding='same', activation='relu'))
    model.add(Conv2D(64, (3,3), padding='same', activation='relu'))
    model.add(BatchNormalization(momentum=momentum))
    
    model.add(MaxPool2D())
    
    model.add(Conv2D(128, (3,3), padding='same', activation='relu'))
    model.add(Conv2D(128, (3,3), padding='same', activation='relu'))
    model.add(BatchNormalization(momentum=momentum))
    
    model.add(MaxPool2D())
    
    model.add(Conv2D(256, (3,3), padding='same', activation='relu'))
    model.add(Conv2D(256, (3,3), padding='same', activation='relu'))
    model.add(BatchNormalization(momentum=momentum))
    
    # flatten...
    model.add(GlobalMaxPool2D())
    return model

# %%
from keras.layers import TimeDistributed, GRU, Dense, Dropout
def action_model(shape=(5, 112, 112, 3), nbout=3):
    # Create our convnet with (112, 112, 3) input shape
    convnet = build_convnet(shape[1:])
    
    # then create our final model
    model = keras.Sequential()
    # add the convnet with (5, 112, 112, 3) shape
    model.add(TimeDistributed(convnet, input_shape=shape))
    # here, you can also use GRU or LSTM
    model.add(LSTM(64,dropout=0.2))
    # and finally, we make a decision network
    model.add(Dense(1024, activation='relu'))
    model.add(Dropout(.5))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(.5))
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(.5))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(nbout, activation='softmax'))
    return model

# %%
INSHAPE=(NBFRAME,) + SIZE + (CHANNELS,) # (5, 112, 112, 3)
model = action_model(INSHAPE, len(classes))
optimizer = keras.optimizers.Adam(0.001)
model.compile(
    optimizer,
    'categorical_crossentropy',
    metrics=['acc']
)

# %%
EPOCHS=75
# create a "chkp" directory before to run that
# because ModelCheckpoint will write models inside
callbacks = [
    keras.callbacks.ReduceLROnPlateau(verbose=1),
    keras.callbacks.ModelCheckpoint(
        './../chkp/weights.{epoch:02d}-{loss:.2f}.hdf5',
        verbose=1),
]
history=model.fit_generator(
    train,
    validation_data=valid,
    verbose=1,
    epochs=EPOCHS,
    callbacks=callbacks
)
# Out:
# Epoch 1/75
# 22/22 [==============================] - 110s 5s/step - loss: 1.4054 - acc: 0.2591 - val_loss: 1.3629 - val_acc: 0.2875
#
# Epoch 00001: saving model to ./../chkp\weights.01-1.38.hdf5
# Epoch 2/75
# 22/22 [==============================] - 83s 4s/step - loss: 1.4335 - acc: 0.2262 - val_loss: 1.3526 - val_acc: 0.3250
#
# Epoch 00002: saving model to ./../chkp\weights.02-1.40.hdf5
# Epoch 3/75
# 22/22 [==============================] - 86s 4s/step - loss: 1.4146 - acc: 0.2134 - val_loss: 1.3591 - val_acc: 0.2500
#
# Epoch 00003: saving model to ./../chkp\weights.03-1.41.hdf5
# Epoch 4/75
# 22/22 [==============================] - 84s 4s/step - loss: 1.4039 - acc: 0.2164 - val_loss: 1.3505 - val_acc: 0.3125
#
# Epoch 00004: saving model to ./../chkp\weights.04-1.38.hdf5
# Epoch 5/75
# 22/22 [==============================] - 85s 4s/step - loss: 1.3651 - acc: 0.3548 - val_loss: 1.3613 - val_acc: 0.3000
#
# Epoch 00005: saving model to ./../chkp\weights.05-1.38.hdf5
# Epoch 6/75
# 22/22 [==============================] - 83s 4s/step - loss: 1.4076 - acc: 0.2447 - val_loss: 1.3371 - val_acc: 0.3125
#
# Epoch 00006: saving model to ./../chkp\weights.06-1.37.hdf5
# Epoch 7/75
# 22/22 [==============================] - 84s 4s/step - loss: 1.3536 - acc: 0.3567 - val_loss: 1.3409 - val_acc: 0.3250
#
# Epoch 00007: saving model to ./../chkp\weights.07-1.38.hdf5
# Epoch 8/75
# 22/22 [==============================] - 85s 4s/step - loss: 1.3600 - acc: 0.3085 - val_loss: 1.3313 - val_acc: 0.3000
#
# Epoch 00008: saving model to ./../chkp\weights.08-1.35.hdf5
# Epoch 9/75
# 22/22 [==============================] - 84s 4s/step - loss: 1.3855 - acc: 0.2666 - val_loss: 1.3238 - val_acc: 0.3375
#
# Epoch 00009: saving model to ./../chkp\weights.09-1.36.hdf5
# Epoch 10/75
# 22/22 [==============================] - 84s 4s/step - loss: 1.3288 - acc: 0.3053 - val_loss: 1.3250 - val_acc: 0.2875
#
# Epoch 00010: saving model to ./../chkp\weights.10-1.35.hdf5
# Epoch 11/75
# 22/22 [==============================] - 84s 4s/step - loss: 1.3782 - acc: 0.2987 - val_loss: 1.3117 - val_acc: 0.3125
#
# Epoch 00011: saving model to ./../chkp\weights.11-1.35.hdf5
# Epoch 12/75
# 22/22 [==============================] - 85s 4s/step - loss: 1.3636 - acc: 0.2000 - val_loss: 1.2971 - val_acc: 0.3250
#
# Epoch 00012: saving model to ./../chkp\weights.12-1.34.hdf5
# Epoch 13/75
# 22/22 [==============================] - 85s 4s/step - loss: 1.3170 - acc: 0.3582 - val_loss: 1.2950 - val_acc: 0.3875
#
# Epoch 00013: saving model to ./../chkp\weights.13-1.30.hdf5
# Epoch 14/75
# 22/22 [==============================] - 84s 4s/step - loss: 1.3020 - acc: 0.3391 - val_loss: 1.3202 - val_acc: 0.3125
#
# Epoch 00014: saving model to ./../chkp\weights.14-1.31.hdf5
# Epoch 15/75
# 22/22 [==============================] - 84s 4s/step - loss: 1.2970 - acc: 0.3478 - val_loss: 1.2313 - val_acc: 0.4125
#
# Epoch 00015: saving model to ./../chkp\weights.15-1.26.hdf5
# Epoch 16/75
# 22/22 [==============================] - 86s 4s/step - loss: 1.3027 - acc: 0.3997 - val_loss: 1.2575 - val_acc: 0.3125
#
# Epoch 00016: saving model to ./../chkp\weights.16-1.32.hdf5
# Epoch 17/75
# 22/22 [==============================] - 89s 4s/step - loss: 1.2930 - acc: 0.3434 - val_loss: 1.2423 - val_acc: 0.4250
#
# Epoch 00017: saving model to ./../chkp\weights.17-1.33.hdf5
# Epoch 18/75
# 22/22 [==============================] - 86s 4s/step - loss: 1.2923 - acc: 0.3526 - val_loss: 1.3261 - val_acc: 0.2875
#
# Epoch 00018: saving model to ./../chkp\weights.18-1.28.hdf5
# Epoch 19/75
# 22/22 [==============================] - 85s 4s/step - loss: 1.3247 - acc: 0.3769 - val_loss: 1.2861 - val_acc: 0.3750
#
# Epoch 00019: saving model to ./../chkp\weights.19-1.31.hdf5
# Epoch 20/75
# 22/22 [==============================] - 85s 4s/step - loss: 1.2170 - acc: 0.4684 - val_loss: 1.1989 - val_acc: 0.4500
#
# Epoch 00020: saving model to ./../chkp\weights.20-1.22.hdf5
# Epoch 21/75
# 22/22 [==============================] - 85s 4s/step - loss: 1.3054 - acc: 0.3521 - val_loss: 1.1704 - val_acc: 0.4375
#
# Epoch 00021: saving model to ./../chkp\weights.21-1.27.hdf5
# Epoch 22/75
# 22/22 [==============================] - 85s 4s/step - loss: 1.1700 - acc: 0.4925 - val_loss: 1.1126 - val_acc: 0.5500
#
# Epoch 00022: saving model to ./../chkp\weights.22-1.23.hdf5
# Epoch 23/75
# 22/22 [==============================] - 88s 4s/step - loss: 1.2990 - acc: 0.4328 - val_loss: 1.2207 - val_acc: 0.4000
#
# Epoch 00023: saving model to ./../chkp\weights.23-1.31.hdf5
# Epoch 24/75
# 22/22 [==============================] - 87s 4s/step - loss: 1.3013 - acc: 0.3415 - val_loss: 1.1346 - val_acc: 0.5125
#
# Epoch 00024: saving model to ./../chkp\weights.24-1.32.hdf5
# Epoch 25/75
# 22/22 [==============================] - 84s 4s/step - loss: 1.2002 - acc: 0.4425 - val_loss: 1.0564 - val_acc: 0.5625
#
# Epoch 00025: saving model to ./../chkp\weights.25-1.21.hdf5
# Epoch 26/75
# 22/22 [==============================] - 86s 4s/step - loss: 1.1800 - acc: 0.4638 - val_loss: 1.0179 - val_acc: 0.4875
#
# Epoch 00026: saving model to ./../chkp\weights.26-1.20.hdf5
# Epoch 27/75
# 22/22 [==============================] - 84s 4s/step - loss: 1.1903 - acc: 0.4211 - val_loss: 1.1417 - val_acc: 0.5125
#
# Epoch 00027: saving model to ./../chkp\weights.27-1.21.hdf5
# Epoch 28/75
# 22/22 [==============================] - 87s 4s/step - loss: 1.1391 - acc: 0.4649 - val_loss: 1.2958 - val_acc: 0.3750
#
# Epoch 00028: saving model to ./../chkp\weights.28-1.22.hdf5
# Epoch 29/75
# 22/22 [==============================] - 85s 4s/step - loss: 1.3905 - acc: 0.3705 - val_loss: 1.1475 - val_acc: 0.5625
#
# Epoch 00029: saving model to ./../chkp\weights.29-1.29.hdf5
# Epoch 30/75
# 22/22 [==============================] - 85s 4s/step - loss: 1.2598 - acc: 0.3782 - val_loss: 1.2340 - val_acc: 0.4625
#
# Epoch 00030: saving model to ./../chkp\weights.30-1.31.hdf5
# Epoch 31/75
# 22/22 [==============================] - 87s 4s/step - loss: 1.2688 - acc: 0.3980 - val_loss: 1.1236 - val_acc: 0.4625
#
# Epoch 00031: saving model to ./../chkp\weights.31-1.28.hdf5
# Epoch 32/75
# 22/22 [==============================] - 84s 4s/step - loss: 1.2906 - acc: 0.3857 - val_loss: 1.2213 - val_acc: 0.5000
#
# Epoch 00032: saving model to ./../chkp\weights.32-1.27.hdf5
# Epoch 33/75
# 22/22 [==============================] - 87s 4s/step - loss: 1.2452 - acc: 0.3882 - val_loss: 1.1662 - val_acc: 0.5125
#
# Epoch 00033: saving model to ./../chkp\weights.33-1.27.hdf5
# Epoch 34/75
# 22/22 [==============================] - 86s 4s/step - loss: 1.1613 - acc: 0.4827 - val_loss: 1.1171 - val_acc: 0.5250
#
# Epoch 00034: saving model to ./../chkp\weights.34-1.22.hdf5
# Epoch 35/75
# 22/22 [==============================] - 86s 4s/step - loss: 1.2191 - acc: 0.4376 - val_loss: 1.0715 - val_acc: 0.5500
#
# Epoch 00035: saving model to ./../chkp\weights.35-1.21.hdf5
# Epoch 36/75
# 22/22 [==============================] - 86s 4s/step - loss: 1.1195 - acc: 0.4769 - val_loss: 1.2598 - val_acc: 0.4125
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00036: saving model to ./../chkp\weights.36-1.12.hdf5
# Epoch 37/75
# 22/22 [==============================] - 86s 4s/step - loss: 1.1785 - acc: 0.4769 - val_loss: 0.9990 - val_acc: 0.5625
#
# Epoch 00037: saving model to ./../chkp\weights.37-1.20.hdf5
# Epoch 38/75
# 22/22 [==============================] - 85s 4s/step - loss: 1.2425 - acc: 0.4353 - val_loss: 1.0328 - val_acc: 0.5375
#
# Epoch 00038: saving model to ./../chkp\weights.38-1.17.hdf5
# Epoch 39/75
# 22/22 [==============================] - 86s 4s/step - loss: 1.1915 - acc: 0.4743 - val_loss: 1.0765 - val_acc: 0.5125
#
# Epoch 00039: saving model to ./../chkp\weights.39-1.17.hdf5
# Epoch 40/75
# 22/22 [==============================] - 86s 4s/step - loss: 1.1214 - acc: 0.4596 - val_loss: 1.0472 - val_acc: 0.5625
#
# Epoch 00040: saving model to ./../chkp\weights.40-1.10.hdf5
# Epoch 41/75
# 22/22 [==============================] - 86s 4s/step - loss: 1.1225 - acc: 0.4544 - val_loss: 1.0261 - val_acc: 0.5125
#
# Epoch 00041: saving model to ./../chkp\weights.41-1.15.hdf5
# Epoch 42/75
# 22/22 [==============================] - 85s 4s/step - loss: 1.1676 - acc: 0.4610 - val_loss: 1.0101 - val_acc: 0.5500
#
# Epoch 00042: saving model to ./../chkp\weights.42-1.14.hdf5
# Epoch 43/75
# 22/22 [==============================] - 88s 4s/step - loss: 1.1283 - acc: 0.4428 - val_loss: 1.0476 - val_acc: 0.5250
#
# Epoch 00043: saving model to ./../chkp\weights.43-1.17.hdf5
# Epoch 44/75
# 22/22 [==============================] - 86s 4s/step - loss: 1.0713 - acc: 0.5413 - val_loss: 1.0298 - val_acc: 0.5250
#
# Epoch 00044: saving model to ./../chkp\weights.44-1.15.hdf5
# Epoch 45/75
# 22/22 [==============================] - 87s 4s/step - loss: 1.0932 - acc: 0.5008 - val_loss: 1.0103 - val_acc: 0.5375
#
# Epoch 00045: saving model to ./../chkp\weights.45-1.12.hdf5
# Epoch 46/75
# 22/22 [==============================] - 86s 4s/step - loss: 1.0586 - acc: 0.5006 - val_loss: 0.9978 - val_acc: 0.5500
#
# Epoch 00046: saving model to ./../chkp\weights.46-1.15.hdf5
# Epoch 47/75
# 22/22 [==============================] - 87s 4s/step - loss: 1.1855 - acc: 0.3996 - val_loss: 0.9959 - val_acc: 0.5250
#
# Epoch 00047: saving model to ./../chkp\weights.47-1.14.hdf5
# Epoch 48/75
# 22/22 [==============================] - 86s 4s/step - loss: 1.0757 - acc: 0.4585 - val_loss: 0.9843 - val_acc: 0.5625
#
# Epoch 00048: saving model to ./../chkp\weights.48-1.08.hdf5
# Epoch 49/75
# 22/22 [==============================] - 86s 4s/step - loss: 1.1339 - acc: 0.4287 - val_loss: 0.9639 - val_acc: 0.5750
#
# Epoch 00049: saving model to ./../chkp\weights.49-1.15.hdf5
# Epoch 50/75
# 22/22 [==============================] - 87s 4s/step - loss: 1.0775 - acc: 0.4641 - val_loss: 1.0022 - val_acc: 0.5125
#
# Epoch 00050: saving model to ./../chkp\weights.50-1.14.hdf5
# Epoch 51/75
# 22/22 [==============================] - 86s 4s/step - loss: 1.0997 - acc: 0.5085 - val_loss: 0.9582 - val_acc: 0.5500
#
# Epoch 00051: saving model to ./../chkp\weights.51-1.09.hdf5
# Epoch 52/75
# 22/22 [==============================] - 85s 4s/step - loss: 1.0981 - acc: 0.5581 - val_loss: 0.9726 - val_acc: 0.5375
#
# Epoch 00052: saving model to ./../chkp\weights.52-1.13.hdf5
# Epoch 53/75
# 22/22 [==============================] - 86s 4s/step - loss: 1.0773 - acc: 0.5168 - val_loss: 0.9452 - val_acc: 0.5625
#
# Epoch 00053: saving model to ./../chkp\weights.53-1.10.hdf5
# Epoch 54/75
# 22/22 [==============================] - 85s 4s/step - loss: 1.1759 - acc: 0.4054 - val_loss: 0.9644 - val_acc: 0.5625
#
# Epoch 00054: saving model to ./../chkp\weights.54-1.08.hdf5
# Epoch 55/75
# 22/22 [==============================] - 83s 4s/step - loss: 1.0815 - acc: 0.4576 - val_loss: 0.9656 - val_acc: 0.5625
#
# Epoch 00055: saving model to ./../chkp\weights.55-1.11.hdf5
# Epoch 56/75
# 22/22 [==============================] - 82s 4s/step - loss: 1.1034 - acc: 0.4903 - val_loss: 0.9304 - val_acc: 0.5625
#
# Epoch 00056: saving model to ./../chkp\weights.56-1.08.hdf5
# Epoch 57/75
# 22/22 [==============================] - 80s 4s/step - loss: 1.1580 - acc: 0.4319 - val_loss: 0.9633 - val_acc: 0.5500
#
# Epoch 00057: saving model to ./../chkp\weights.57-1.12.hdf5
# Epoch 58/75
# 22/22 [==============================] - 83s 4s/step - loss: 1.1176 - acc: 0.5102 - val_loss: 0.9528 - val_acc: 0.5500
#
# Epoch 00058: saving model to ./../chkp\weights.58-1.13.hdf5
# Epoch 59/75
# 22/22 [==============================] - 81s 4s/step - loss: 1.1222 - acc: 0.4188 - val_loss: 0.9218 - val_acc: 0.5750
#
# Epoch 00059: saving model to ./../chkp\weights.59-1.07.hdf5
# Epoch 60/75
# 22/22 [==============================] - 82s 4s/step - loss: 1.0772 - acc: 0.4903 - val_loss: 0.9388 - val_acc: 0.5500
#
# Epoch 00060: saving model to ./../chkp\weights.60-1.09.hdf5
# Epoch 61/75
# 22/22 [==============================] - 80s 4s/step - loss: 1.1097 - acc: 0.4106 - val_loss: 0.9488 - val_acc: 0.5375
#
# Epoch 00061: saving model to ./../chkp\weights.61-1.09.hdf5
# Epoch 62/75
# 22/22 [==============================] - 80s 4s/step - loss: 1.1651 - acc: 0.3984 - val_loss: 0.9159 - val_acc: 0.5625
#
# Epoch 00062: saving model to ./../chkp\weights.62-1.08.hdf5
# Epoch 63/75
# 22/22 [==============================] - 82s 4s/step - loss: 1.1004 - acc: 0.4686 - val_loss: 0.9620 - val_acc: 0.6625
#
# Epoch 00063: saving model to ./../chkp\weights.63-1.14.hdf5
# Epoch 64/75
# 22/22 [==============================] - 80s 4s/step - loss: 1.0476 - acc: 0.5290 - val_loss: 0.9084 - val_acc: 0.6125
#
# Epoch 00064: saving model to ./../chkp\weights.64-1.04.hdf5
# Epoch 65/75
# 22/22 [==============================] - 80s 4s/step - loss: 1.0901 - acc: 0.4849 - val_loss: 0.9114 - val_acc: 0.5500
#
# Epoch 00065: saving model to ./../chkp\weights.65-1.07.hdf5
# Epoch 66/75
# 22/22 [==============================] - 79s 4s/step - loss: 1.0069 - acc: 0.5063 - val_loss: 0.9489 - val_acc: 0.5375
#
# Epoch 00066: saving model to ./../chkp\weights.66-1.03.hdf5
# Epoch 67/75
# 22/22 [==============================] - 81s 4s/step - loss: 1.0960 - acc: 0.4596 - val_loss: 0.8878 - val_acc: 0.5500
#
# Epoch 00067: saving model to ./../chkp\weights.67-1.09.hdf5
# Epoch 68/75
# 22/22 [==============================] - 79s 4s/step - loss: 1.0840 - acc: 0.4204 - val_loss: 0.9029 - val_acc: 0.6625
#
# Epoch 00068: saving model to ./../chkp\weights.68-1.07.hdf5
# Epoch 69/75
# 22/22 [==============================] - 80s 4s/step - loss: 1.1316 - acc: 0.4804 - val_loss: 0.9456 - val_acc: 0.5375
#
# Epoch 00069: saving model to ./../chkp\weights.69-1.06.hdf5
# Epoch 70/75
# 22/22 [==============================] - 80s 4s/step - loss: 1.0622 - acc: 0.5529 - val_loss: 0.8889 - val_acc: 0.5500
#
# Epoch 00070: saving model to ./../chkp\weights.70-1.02.hdf5
# Epoch 71/75
# 22/22 [==============================] - 79s 4s/step - loss: 1.0820 - acc: 0.4346 - val_loss: 0.9065 - val_acc: 0.5500
#
# Epoch 00071: saving model to ./../chkp\weights.71-1.09.hdf5
# Epoch 72/75
# 22/22 [==============================] - 79s 4s/step - loss: 1.1092 - acc: 0.3696 - val_loss: 0.9058 - val_acc: 0.5250
#
# Epoch 00072: saving model to ./../chkp\weights.72-1.05.hdf5
# Epoch 73/75
# 22/22 [==============================] - 81s 4s/step - loss: 1.1027 - acc: 0.4456 - val_loss: 0.8743 - val_acc: 0.6000
#
# Epoch 00073: saving model to ./../chkp\weights.73-1.07.hdf5
# Epoch 74/75
# 22/22 [==============================] - 79s 4s/step - loss: 1.0548 - acc: 0.5181 - val_loss: 0.8636 - val_acc: 0.6750
#
# Epoch 00074: saving model to ./../chkp\weights.74-1.06.hdf5
# Epoch 75/75
# 22/22 [==============================] - 80s 4s/step - loss: 0.9775 - acc: 0.5704 - val_loss: 0.8689 - val_acc: 0.6625
#
# Epoch 00075: saving model to ./../chkp\weights.75-1.01.hdf5

# %%
history.history['acc']
# Out:
# [0.2954545319080353,
#  0.27840909361839294,
#  0.22727273404598236,
#  0.23295454680919647,
#  0.3125,
#  0.2670454680919647,
#  0.28977271914482117,
#  0.27272728085517883,
#  0.3068181872367859,
#  0.3068181872367859,
#  0.33522728085517883,
#  0.27840909361839294,
#  0.375,
#  0.33522728085517883,
#  0.41477271914482117,
#  0.34659090638160706,
#  0.3068181872367859,
#  0.3920454680919647,
#  0.3636363744735718,
#  0.4375,
#  0.39772728085517883,
#  0.47159090638160706,
#  0.40909090638160706,
#  0.34090909361839294,
#  0.4545454680919647,
#  0.4488636255264282,
#  0.4431818127632141,
#  0.47159090638160706,
#  0.46022728085517883,
#  0.39772728085517883,
#  0.41477271914482117,
#  0.4204545319080353,
#  0.3920454680919647,
#  0.41477271914482117,
#  0.47159090638160706,
#  0.46022728085517883,
#  0.47159090638160706,
#  0.4545454680919647,
#  0.4545454680919647,
#  0.46022728085517883,
#  0.4375,
#  0.46590909361839294,
#  0.4375,
#  0.46590909361839294,
#  0.4886363744735718,
#  0.46590909361839294,
#  0.4375,
#  0.46590909361839294,
#  0.4318181872367859,
#  0.41477271914482117,
#  0.4829545319080353,
#  0.4886363744735718,
#  0.4829545319080353,
#  0.5,
#  0.4431818127632141,
#  0.4829545319080353,
#  0.46590909361839294,
#  0.5056818127632141,
#  0.47159090638160706,
#  0.4545454680919647,
#  0.4261363744735718,
#  0.4886363744735718,
#  0.4488636255264282,
#  0.5113636255264282,
#  0.5056818127632141,
#  0.5113636255264282,
#  0.47159090638160706,
#  0.46590909361839294,
#  0.5284090638160706,
#  0.5511363744735718,
#  0.4318181872367859,
#  0.5,
#  0.4943181872367859,
#  0.4886363744735718,
#  0.5284090638160706]

# %%
history.history['val_acc']
# Out:
# [0.2874999940395355,
#  0.32499998807907104,
#  0.25,
#  0.3125,
#  0.30000001192092896,
#  0.3125,
#  0.32499998807907104,
#  0.30000001192092896,
#  0.3375000059604645,
#  0.2874999940395355,
#  0.3125,
#  0.32499998807907104,
#  0.38749998807907104,
#  0.3125,
#  0.4124999940395355,
#  0.3125,
#  0.42500001192092896,
#  0.2874999940395355,
#  0.375,
#  0.44999998807907104,
#  0.4375,
#  0.550000011920929,
#  0.4000000059604645,
#  0.512499988079071,
#  0.5625,
#  0.48750001192092896,
#  0.512499988079071,
#  0.375,
#  0.5625,
#  0.4625000059604645,
#  0.4625000059604645,
#  0.5,
#  0.512499988079071,
#  0.5249999761581421,
#  0.550000011920929,
#  0.4124999940395355,
#  0.5625,
#  0.5375000238418579,
#  0.512499988079071,
#  0.5625,
#  0.512499988079071,
#  0.550000011920929,
#  0.5249999761581421,
#  0.5249999761581421,
#  0.5375000238418579,
#  0.550000011920929,
#  0.5249999761581421,
#  0.5625,
#  0.574999988079071,
#  0.512499988079071,
#  0.550000011920929,
#  0.5375000238418579,
#  0.5625,
#  0.5625,
#  0.5625,
#  0.5625,
#  0.550000011920929,
#  0.550000011920929,
#  0.574999988079071,
#  0.550000011920929,
#  0.5375000238418579,
#  0.5625,
#  0.6625000238418579,
#  0.612500011920929,
#  0.550000011920929,
#  0.5375000238418579,
#  0.550000011920929,
#  0.6625000238418579,
#  0.5375000238418579,
#  0.550000011920929,
#  0.550000011920929,
#  0.5249999761581421,
#  0.6000000238418579,
#  0.675000011920929,
#  0.6625000238418579]

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['acc'],label='acc')
plt.plot(history.history['val_acc'],label='val acc')
plt.show()
