# %% [markdown]
# <h1> Recherche </h1>

# %% [markdown]
# <h2>Etape 1 : générer des vidéos</h2>

# %%
from moviepy.video.io.ffmpeg_tools import ffmpeg_extract_subclip
from moviepy.editor import VideoFileClip

def reshape_clip(name,num):
    clip = VideoFileClip(name)
    clip=clip.resize((360,360))
    clip.write_videofile(name.replace("#.mp4","@#.mp4"))
    print(clip.duration,"secondes")
    durée=clip.duration
    echelon=durée/num
    del clip
    for i in range(num):
        start_time,end_time=i*echelon,(i+1)*echelon
        ffmpeg_extract_subclip(name.replace("#.mp4","@#.mp4"), start_time, end_time, targetname=name.replace("#.mp4","{}.mp4".format(i)))
    return True
val=12
reshape_clip("./video/fache/fache#.mp4",val)
reshape_clip("./video/fache/maxou_fache#.mp4",val)
reshape_clip("./video/fache/antoju_fache#.mp4",val)
reshape_clip("./video/fache/theo_1#.mp4",val)
reshape_clip("./video/fache/theo_2#.mp4",val)
reshape_clip("./video/deg/theo_1#.mp4",val)
reshape_clip("./video/deg/theo_2#.mp4",val)
reshape_clip("./video/heureux/theo_1#.mp4",val)
#reshape_clip("./video/fache/s_fache#.mp4",8)
reshape_clip("./video/heureux/heureux#.mp4",val)
reshape_clip("./video/heureux/maxou_heureux#.mp4",val)
#
reshape_clip("./video/heureux/antoine_heureux#.mp4",val)
reshape_clip("./video/heureux/antoine2_heureux#.mp4",val)
reshape_clip("./video/heureux/antoju_heureux#.mp4",val)
reshape_clip("./video/triste/triste#.mp4",val)
reshape_clip("./video/triste/antoine_triste#.mp4",val)
reshape_clip("./video/triste/maxou_triste#.mp4",val)
reshape_clip("./video/deg/deg#.mp4",val)
reshape_clip("./video/deg/antoine_deg#.mp4",val)
reshape_clip("./video/deg/sound_deg#.mp4",val)
# Out:
# Moviepy - Building video ./video/fache/fache@#.mp4.
# MoviePy - Writing audio in fache@#TEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video ./video/fache/fache@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/fache/fache@#.mp4
# 13.84 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# t:   0%|          | 0/98 [00:00<?, ?it/s, now=None]
# Moviepy - Building video ./video/fache/maxou_fache@#.mp4.
# MoviePy - Writing audio in maxou_fache@#TEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video ./video/fache/maxou_fache@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/fache/maxou_fache@#.mp4
# 12.67 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# chunk:  64%|██████▍   | 264/411 [00:00<00:00, 1083.52it/s, now=None]
# Moviepy - Building video ./video/fache/antoju_fache@#.mp4.
# MoviePy - Writing audio in antoju_fache@#TEMP_MPY_wvf_snd.mp3
# t:   3%|▎         | 17/540 [00:00<00:07, 73.21it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video ./video/fache/antoju_fache@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/fache/antoju_fache@#.mp4
# 18.6 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# t:  19%|█▊        | 18/97 [00:00<00:01, 77.35it/s, now=None]
# Moviepy - Building video ./video/fache/theo_1@#.mp4.
# Moviepy - Writing video ./video/fache/theo_1@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/fache/theo_1@#.mp4
# 5.79 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# t:   7%|▋         | 8/110 [00:00<00:01, 73.39it/s, now=None]
# Moviepy - Building video ./video/fache/theo_2@#.mp4.
# Moviepy - Writing video ./video/fache/theo_2@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/fache/theo_2@#.mp4
# 6.56 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# t:   6%|▌         | 7/117 [00:00<00:01, 68.96it/s, now=None]
# Moviepy - Building video ./video/deg/theo_1@#.mp4.
# Moviepy - Writing video ./video/deg/theo_1@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/deg/theo_1@#.mp4
# 6.99 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# t:   7%|▋         | 8/115 [00:00<00:01, 72.73it/s, now=None]
# Moviepy - Building video ./video/deg/theo_2@#.mp4.
# Moviepy - Writing video ./video/deg/theo_2@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/deg/theo_2@#.mp4
# 6.87 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Building video ./video/heureux/theo_1@#.mp4.
# Moviepy - Writing video ./video/heureux/theo_1@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/heureux/theo_1@#.mp4
# 10.0 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# t:   0%|          | 0/89 [00:00<?, ?it/s, now=None]
# Moviepy - Building video ./video/heureux/heureux@#.mp4.
# MoviePy - Writing audio in heureux@#TEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video ./video/heureux/heureux@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/heureux/heureux@#.mp4
# 11.49 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Building video ./video/heureux/maxou_heureux@#.mp4.
# MoviePy - Writing audio in maxou_heureux@#TEMP_MPY_wvf_snd.mp3
# t:  14%|█▍        | 16/116 [00:00<00:00, 155.34it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video ./video/heureux/maxou_heureux@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/heureux/maxou_heureux@#.mp4
# 15.03 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# chunk:  66%|██████▋   | 263/396 [00:00<00:00, 1115.81it/s, now=None]
# Moviepy - Building video ./video/heureux/antoine_heureux@#.mp4.
# MoviePy - Writing audio in antoine_heureux@#TEMP_MPY_wvf_snd.mp3
# t:   3%|▎         | 18/520 [00:00<00:06, 76.54it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video ./video/heureux/antoine_heureux@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/heureux/antoine_heureux@#.mp4
# 17.93 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# chunk:  24%|██▎       | 84/356 [00:00<00:00, 839.98it/s, now=None]
# Moviepy - Building video ./video/heureux/antoine2_heureux@#.mp4.
# MoviePy - Writing audio in antoine2_heureux@#TEMP_MPY_wvf_snd.mp3
# t:   1%|▏         | 7/469 [00:00<00:07, 63.64it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video ./video/heureux/antoine2_heureux@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/heureux/antoine2_heureux@#.mp4
# 16.14 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# chunk:  26%|██▌       | 91/352 [00:00<00:00, 909.71it/s, now=None]
# Moviepy - Building video ./video/heureux/antoju_heureux@#.mp4.
# MoviePy - Writing audio in antoju_heureux@#TEMP_MPY_wvf_snd.mp3
# t:   2%|▏         | 7/462 [00:00<00:06, 69.27it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video ./video/heureux/antoju_heureux@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/heureux/antoju_heureux@#.mp4
# 15.93 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# t:   0%|          | 0/100 [00:00<?, ?it/s, now=None]
# Moviepy - Building video ./video/triste/triste@#.mp4.
# MoviePy - Writing audio in triste@#TEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video ./video/triste/triste@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/triste/triste@#.mp4
# 12.93 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# chunk:  23%|██▎       | 90/384 [00:00<00:00, 899.61it/s, now=None]
# Moviepy - Building video ./video/triste/antoine_triste@#.mp4.
# MoviePy - Writing audio in antoine_triste@#TEMP_MPY_wvf_snd.mp3
# t:   1%|▏         | 7/504 [00:00<00:07, 65.39it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video ./video/triste/antoine_triste@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/triste/antoine_triste@#.mp4
# 17.37 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# t:   0%|          | 0/101 [00:00<?, ?it/s, now=None]
# Moviepy - Building video ./video/triste/maxou_triste@#.mp4.
# MoviePy - Writing audio in maxou_triste@#TEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video ./video/triste/maxou_triste@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/triste/maxou_triste@#.mp4
# 13.07 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# t:   0%|          | 0/97 [00:00<?, ?it/s, now=None]
# Moviepy - Building video ./video/deg/deg@#.mp4.
# MoviePy - Writing audio in deg@#TEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video ./video/deg/deg@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/deg/deg@#.mp4
# 12.55 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# chunk:   8%|▊         | 28/371 [00:00<00:01, 277.22it/s, now=None]
# Moviepy - Building video ./video/deg/antoine_deg@#.mp4.
# MoviePy - Writing audio in antoine_deg@#TEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video ./video/deg/antoine_deg@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/deg/antoine_deg@#.mp4
# 16.81 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Building video ./video/deg/sound_deg@#.mp4.
# MoviePy - Writing audio in sound_deg@#TEMP_MPY_wvf_snd.mp3
# t:   4%|▍         | 13/297 [00:00<00:02, 125.99it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video ./video/deg/sound_deg@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/deg/sound_deg@#.mp4
# 10.22 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# True

# %%
reshape_clip("./video/deg/sound_deg#.mp4",val)
#reshape_clip("./video/heureux/sound_heureux#.mp4",val)
# Out:
# chunk:  41%|████      | 93/226 [00:00<00:00, 920.65it/s, now=None]
# Moviepy - Building video ./video/deg/sound_deg@#.mp4.
# MoviePy - Writing audio in sound_deg@#TEMP_MPY_wvf_snd.mp3
# t:   4%|▍         | 12/297 [00:00<00:02, 116.51it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video ./video/deg/sound_deg@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/deg/sound_deg@#.mp4
# 10.22 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# True

# %% [markdown]
# <h2>Etape 2 : extraire les vidéos pour créer le dataset</h2>

# %%
import os
import glob
import keras
from keras_video import VideoFrameGenerator
# use sub directories names as classes
classes = [i.split(os.path.sep)[1] for i in glob.glob('./video/*') if "#" not in i]
classes.sort()
# some global params
SIZE = (112, 112)
CHANNELS = 3
NBFRAME = 5
BS = 8
# pattern to get videos and classes
glob_pattern='./video/{classname}/*.mp4'
# for data augmentation
data_aug = keras.preprocessing.image.ImageDataGenerator(
    zoom_range=.1,
    horizontal_flip=True,
    rotation_range=8,
    width_shift_range=.2,
    height_shift_range=.2)
# Create video frame generator
train = VideoFrameGenerator(
    classes=classes, 
    glob_pattern=glob_pattern,
    nb_frames=NBFRAME,
    split=.33, 
    shuffle=True,
    batch_size=BS,
    target_shape=SIZE,
    nb_channel=CHANNELS,
    transformation=data_aug,
    use_frame_cache=True)
# Out:
# Warning, `split` argument is replaced by `split_val`, please condider to change your source code.The `split` argument will be removed in future releases.
# class deg, validation count: 23, train count: 47
# class fache, validation count: 23, train count: 47
# class heureux, validation count: 27, train count: 57
# class triste, validation count: 13, train count: 29
# Total data: 4 classes for 180 files for train

# %%
valid = train.get_validation_generator()
# Out:
# Total data: 4 classes for 86 files for validation

# %%
import keras_video.utils
keras_video.utils.show_sample(train)

# %% [markdown]
# <h2>Etape 3 : création du modèle</h2>

# %%
from keras.layers import Conv2D, BatchNormalization, \
    MaxPool2D, GlobalMaxPool2D
def build_convnet(shape=(112, 112, 3)):
    momentum = .9
    model = keras.Sequential()
    model.add(Conv2D(64, (3,3), input_shape=shape,
        padding='same', activation='relu'))
    model.add(Conv2D(64, (3,3), padding='same', activation='relu'))
    model.add(BatchNormalization(momentum=momentum))
    
    model.add(MaxPool2D())
    
    model.add(Conv2D(128, (3,3), padding='same', activation='relu'))
    model.add(Conv2D(128, (3,3), padding='same', activation='relu'))
    model.add(BatchNormalization(momentum=momentum))
    
    model.add(MaxPool2D())
    
    model.add(Conv2D(256, (3,3), padding='same', activation='relu'))
    model.add(Conv2D(256, (3,3), padding='same', activation='relu'))
    model.add(BatchNormalization(momentum=momentum))
    
    model.add(MaxPool2D())
    
    model.add(Conv2D(512, (3,3), padding='same', activation='relu'))
    model.add(Conv2D(512, (3,3), padding='same', activation='relu'))
    model.add(BatchNormalization(momentum=momentum))
    
    # flatten...
    model.add(GlobalMaxPool2D())
    return model

# %%
from keras.layers import TimeDistributed, GRU, Dense, Dropout
def action_model(shape=(5, 112, 112, 3), nbout=3):
    # Create our convnet with (112, 112, 3) input shape
    convnet = build_convnet(shape[1:])
    
    # then create our final model
    model = keras.Sequential()
    # add the convnet with (5, 112, 112, 3) shape
    model.add(TimeDistributed(convnet, input_shape=shape))
    # here, you can also use GRU or LSTM
    model.add(GRU(64,dropout=0.2))
    # and finally, we make a decision network
    model.add(Dense(1024, activation='relu'))
    model.add(Dropout(.5))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(.5))
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(.5))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(nbout, activation='softmax'))
    return model

# %%
INSHAPE=(NBFRAME,) + SIZE + (CHANNELS,) # (5, 112, 112, 3)
model = action_model(INSHAPE, len(classes))
optimizer = keras.optimizers.Adam(0.001)
model.compile(
    optimizer,
    'categorical_crossentropy',
    metrics=['acc']
)

# %% [markdown]
# <h2>Etape 4 : Entraînement du modèle</h2>

# %%
EPOCHS=50
# create a "chkp" directory before to run that
# because ModelCheckpoint will write models inside
callbacks = [
    keras.callbacks.ReduceLROnPlateau(verbose=1),
    keras.callbacks.ModelCheckpoint(
        './../chkp/weights.{epoch:02d}-{loss:.2f}.hdf5',
        verbose=1),
]
history=model.fit_generator(
    train,
    validation_data=valid,
    verbose=1,
    epochs=EPOCHS,
    callbacks=callbacks
)
# Out:
# Epoch 1/50
# 22/22 [==============================] - 122s 5s/step - loss: 1.4745 - acc: 0.2705 - val_loss: 1.3731 - val_acc: 0.3375
#
# Epoch 00001: saving model to ./../chkp\weights.01-1.47.hdf5
# Epoch 2/50
# 22/22 [==============================] - 100s 5s/step - loss: 1.4612 - acc: 0.2382 - val_loss: 1.3528 - val_acc: 0.3750
#
# Epoch 00002: saving model to ./../chkp\weights.02-1.45.hdf5
# Epoch 3/50
# 22/22 [==============================] - 107s 5s/step - loss: 1.4115 - acc: 0.3006 - val_loss: 1.3333 - val_acc: 0.3625
#
# Epoch 00003: saving model to ./../chkp\weights.03-1.41.hdf5
# Epoch 4/50
# 22/22 [==============================] - 113s 5s/step - loss: 1.3837 - acc: 0.2174 - val_loss: 1.3352 - val_acc: 0.3250
#
# Epoch 00004: saving model to ./../chkp\weights.04-1.37.hdf5
# Epoch 5/50
# 22/22 [==============================] - 114s 5s/step - loss: 1.3664 - acc: 0.3014 - val_loss: 1.3605 - val_acc: 0.2750
#
# Epoch 00005: saving model to ./../chkp\weights.05-1.43.hdf5
# Epoch 6/50
# 22/22 [==============================] - 108s 5s/step - loss: 1.4025 - acc: 0.1992 - val_loss: 1.3521 - val_acc: 0.2000
#
# Epoch 00006: saving model to ./../chkp\weights.06-1.39.hdf5
# Epoch 7/50
# 22/22 [==============================] - 103s 5s/step - loss: 1.3708 - acc: 0.2639 - val_loss: 1.3467 - val_acc: 0.3000
#
# Epoch 00007: saving model to ./../chkp\weights.07-1.39.hdf5
# Epoch 8/50
# 22/22 [==============================] - 108s 5s/step - loss: 1.3585 - acc: 0.3032 - val_loss: 1.3546 - val_acc: 0.3750
#
# Epoch 00008: saving model to ./../chkp\weights.08-1.35.hdf5
# Epoch 9/50
# 22/22 [==============================] - 107s 5s/step - loss: 1.3923 - acc: 0.2899 - val_loss: 1.3377 - val_acc: 0.2875
#
# Epoch 00009: saving model to ./../chkp\weights.09-1.39.hdf5
# Epoch 10/50
# 22/22 [==============================] - 113s 5s/step - loss: 1.3859 - acc: 0.3260 - val_loss: 1.3013 - val_acc: 0.4125
#
# Epoch 00010: saving model to ./../chkp\weights.10-1.38.hdf5
# Epoch 11/50
# 22/22 [==============================] - 109s 5s/step - loss: 1.3476 - acc: 0.2287 - val_loss: 1.3141 - val_acc: 0.3250
#
# Epoch 00011: saving model to ./../chkp\weights.11-1.34.hdf5
# Epoch 12/50
# 22/22 [==============================] - 112s 5s/step - loss: 1.3015 - acc: 0.4076 - val_loss: 1.3207 - val_acc: 0.2500
#
# Epoch 00012: saving model to ./../chkp\weights.12-1.30.hdf5
# Epoch 13/50
# 22/22 [==============================] - 105s 5s/step - loss: 1.3155 - acc: 0.3618 - val_loss: 1.2581 - val_acc: 0.2375
#
# Epoch 00013: saving model to ./../chkp\weights.13-1.32.hdf5
# Epoch 14/50
# 22/22 [==============================] - 106s 5s/step - loss: 1.3613 - acc: 0.2968 - val_loss: 1.2768 - val_acc: 0.3750
#
# Epoch 00014: saving model to ./../chkp\weights.14-1.35.hdf5
# Epoch 15/50
# 22/22 [==============================] - 104s 5s/step - loss: 1.2894 - acc: 0.3470 - val_loss: 1.2176 - val_acc: 0.3125
#
# Epoch 00015: saving model to ./../chkp\weights.15-1.28.hdf5
# Epoch 16/50
# 22/22 [==============================] - 117s 5s/step - loss: 1.2572 - acc: 0.2978 - val_loss: 1.2936 - val_acc: 0.3250
#
# Epoch 00016: saving model to ./../chkp\weights.16-1.31.hdf5
# Epoch 17/50
# 22/22 [==============================] - 113s 5s/step - loss: 1.3173 - acc: 0.3275 - val_loss: 1.2477 - val_acc: 0.3250
#
# Epoch 00017: saving model to ./../chkp\weights.17-1.29.hdf5
# Epoch 18/50
# 22/22 [==============================] - 107s 5s/step - loss: 1.3133 - acc: 0.3498 - val_loss: 1.2434 - val_acc: 0.3250
#
# Epoch 00018: saving model to ./../chkp\weights.18-1.30.hdf5
# Epoch 19/50
# 22/22 [==============================] - 107s 5s/step - loss: 1.2940 - acc: 0.3659 - val_loss: 1.2332 - val_acc: 0.2875
#
# Epoch 00019: saving model to ./../chkp\weights.19-1.30.hdf5
# Epoch 20/50
# 22/22 [==============================] - 103s 5s/step - loss: 1.3821 - acc: 0.3088 - val_loss: 1.3001 - val_acc: 0.3000
#
# Epoch 00020: saving model to ./../chkp\weights.20-1.34.hdf5
# Epoch 21/50
# 22/22 [==============================] - 109s 5s/step - loss: 1.2762 - acc: 0.4020 - val_loss: 1.2601 - val_acc: 0.2750
#
# Epoch 00021: saving model to ./../chkp\weights.21-1.30.hdf5
# Epoch 22/50
# 22/22 [==============================] - 105s 5s/step - loss: 1.2674 - acc: 0.3539 - val_loss: 1.2593 - val_acc: 0.3000
#
# Epoch 00022: saving model to ./../chkp\weights.22-1.30.hdf5
# Epoch 23/50
# 22/22 [==============================] - 106s 5s/step - loss: 1.3087 - acc: 0.3155 - val_loss: 1.2806 - val_acc: 0.3000
#
# Epoch 00023: saving model to ./../chkp\weights.23-1.31.hdf5
# Epoch 24/50
# 22/22 [==============================] - 105s 5s/step - loss: 1.3071 - acc: 0.3214 - val_loss: 1.2536 - val_acc: 0.4125
#
# Epoch 00024: saving model to ./../chkp\weights.24-1.32.hdf5
# Epoch 25/50
# 22/22 [==============================] - 104s 5s/step - loss: 1.2323 - acc: 0.3672 - val_loss: 1.2641 - val_acc: 0.2625
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00025: saving model to ./../chkp\weights.25-1.25.hdf5
# Epoch 26/50
# 22/22 [==============================] - 103s 5s/step - loss: 1.3173 - acc: 0.2989 - val_loss: 1.2605 - val_acc: 0.2375
#
# Epoch 00026: saving model to ./../chkp\weights.26-1.32.hdf5
# Epoch 27/50
# 22/22 [==============================] - 98s 4s/step - loss: 1.2499 - acc: 0.3481 - val_loss: 1.2363 - val_acc: 0.3250
#
# Epoch 00027: saving model to ./../chkp\weights.27-1.26.hdf5
# Epoch 28/50
# 22/22 [==============================] - 96s 4s/step - loss: 1.2886 - acc: 0.3245 - val_loss: 1.2496 - val_acc: 0.2625
#
# Epoch 00028: saving model to ./../chkp\weights.28-1.30.hdf5
# Epoch 29/50
# 22/22 [==============================] - 98s 4s/step - loss: 1.2232 - acc: 0.3595 - val_loss: 1.2324 - val_acc: 0.3000
#
# Epoch 00029: saving model to ./../chkp\weights.29-1.24.hdf5
# Epoch 30/50
# 22/22 [==============================] - 97s 4s/step - loss: 1.2600 - acc: 0.3430 - val_loss: 1.2357 - val_acc: 0.2875
#
# Epoch 00030: saving model to ./../chkp\weights.30-1.26.hdf5
# Epoch 31/50
# 22/22 [==============================] - 97s 4s/step - loss: 1.2668 - acc: 0.2585 - val_loss: 1.2304 - val_acc: 0.2875
#
# Epoch 00031: saving model to ./../chkp\weights.31-1.27.hdf5
# Epoch 32/50
# 22/22 [==============================] - 96s 4s/step - loss: 1.1966 - acc: 0.4156 - val_loss: 1.2228 - val_acc: 0.3375
#
# Epoch 00032: saving model to ./../chkp\weights.32-1.21.hdf5
# Epoch 33/50
# 22/22 [==============================] - 98s 4s/step - loss: 1.2904 - acc: 0.3097 - val_loss: 1.2294 - val_acc: 0.3375
#
# Epoch 00033: saving model to ./../chkp\weights.33-1.26.hdf5
# Epoch 34/50
# 22/22 [==============================] - 96s 4s/step - loss: 1.2208 - acc: 0.3660 - val_loss: 1.2322 - val_acc: 0.3500
#
# Epoch 00034: saving model to ./../chkp\weights.34-1.22.hdf5
# Epoch 35/50
# 22/22 [==============================] - 97s 4s/step - loss: 1.2477 - acc: 0.3728 - val_loss: 1.2142 - val_acc: 0.3375
#
# Epoch 00035: saving model to ./../chkp\weights.35-1.27.hdf5
# Epoch 36/50
# 22/22 [==============================] - 97s 4s/step - loss: 1.2283 - acc: 0.3883 - val_loss: 1.2227 - val_acc: 0.3500
#
# Epoch 00036: saving model to ./../chkp\weights.36-1.21.hdf5
# Epoch 37/50
# 22/22 [==============================] - 97s 4s/step - loss: 1.2753 - acc: 0.3904 - val_loss: 1.2153 - val_acc: 0.3625
#
# Epoch 00037: saving model to ./../chkp\weights.37-1.28.hdf5
# Epoch 38/50
# 22/22 [==============================] - 102s 5s/step - loss: 1.2046 - acc: 0.3983 - val_loss: 1.2216 - val_acc: 0.3625
#
# Epoch 00038: saving model to ./../chkp\weights.38-1.22.hdf5
# Epoch 39/50
# 22/22 [==============================] - 104s 5s/step - loss: 1.2104 - acc: 0.3625 - val_loss: 1.2185 - val_acc: 0.3625
#
# Epoch 00039: saving model to ./../chkp\weights.39-1.22.hdf5
# Epoch 40/50
# 22/22 [==============================] - 116s 5s/step - loss: 1.3063 - acc: 0.2920 - val_loss: 1.2205 - val_acc: 0.3500
#
# Epoch 00040: saving model to ./../chkp\weights.40-1.26.hdf5
# Epoch 41/50
# 22/22 [==============================] - 112s 5s/step - loss: 1.2795 - acc: 0.4084 - val_loss: 1.2105 - val_acc: 0.3750
#
# Epoch 00041: saving model to ./../chkp\weights.41-1.26.hdf5
# Epoch 42/50
# 22/22 [==============================] - 105s 5s/step - loss: 1.2838 - acc: 0.3221 - val_loss: 1.1991 - val_acc: 0.3625
#
# Epoch 00042: saving model to ./../chkp\weights.42-1.26.hdf5
# Epoch 43/50
# 22/22 [==============================] - 105s 5s/step - loss: 1.2107 - acc: 0.4131 - val_loss: 1.2057 - val_acc: 0.3500
#
# Epoch 00043: saving model to ./../chkp\weights.43-1.22.hdf5
# Epoch 44/50
# 22/22 [==============================] - 105s 5s/step - loss: 1.1848 - acc: 0.4735 - val_loss: 1.2044 - val_acc: 0.3500
#
# Epoch 00044: saving model to ./../chkp\weights.44-1.20.hdf5
# Epoch 45/50
# 22/22 [==============================] - 105s 5s/step - loss: 1.2365 - acc: 0.3777 - val_loss: 1.2061 - val_acc: 0.3500
#
# Epoch 00045: saving model to ./../chkp\weights.45-1.23.hdf5
# Epoch 46/50
# 22/22 [==============================] - 105s 5s/step - loss: 1.2287 - acc: 0.3468 - val_loss: 1.1792 - val_acc: 0.3500
#
# Epoch 00046: saving model to ./../chkp\weights.46-1.24.hdf5
# Epoch 47/50
# 22/22 [==============================] - 105s 5s/step - loss: 1.2621 - acc: 0.3342 - val_loss: 1.2035 - val_acc: 0.3500
#
# Epoch 00047: saving model to ./../chkp\weights.47-1.27.hdf5
# Epoch 48/50
# 22/22 [==============================] - 104s 5s/step - loss: 1.2261 - acc: 0.4314 - val_loss: 1.1990 - val_acc: 0.3625
#
# Epoch 00048: saving model to ./../chkp\weights.48-1.22.hdf5
# Epoch 49/50
# 22/22 [==============================] - 105s 5s/step - loss: 1.1922 - acc: 0.4532 - val_loss: 1.1892 - val_acc: 0.3500
#
# Epoch 00049: saving model to ./../chkp\weights.49-1.21.hdf5
# Epoch 50/50
# 22/22 [==============================] - 102s 5s/step - loss: 1.2048 - acc: 0.4135 - val_loss: 1.1696 - val_acc: 0.3875
#
# Epoch 00050: saving model to ./../chkp\weights.50-1.20.hdf5

# %%
history.history['acc']
# Out:
# [0.27272728085517883,
#  0.23295454680919647,
#  0.27272728085517883,
#  0.2670454680919647,
#  0.27272728085517883,
#  0.22159090638160706,
#  0.27272728085517883,
#  0.3011363744735718,
#  0.27840909361839294,
#  0.3011363744735718,
#  0.2670454680919647,
#  0.3693181872367859,
#  0.34090909361839294,
#  0.28977271914482117,
#  0.34659090638160706,
#  0.2954545319080353,
#  0.3579545319080353,
#  0.33522728085517883,
#  0.35227271914482117,
#  0.3238636255264282,
#  0.3693181872367859,
#  0.35227271914482117,
#  0.3295454680919647,
#  0.2954545319080353,
#  0.35227271914482117,
#  0.2556818127632141,
#  0.3636363744735718,
#  0.33522728085517883,
#  0.3011363744735718,
#  0.33522728085517883,
#  0.2954545319080353,
#  0.3920454680919647,
#  0.3181818127632141,
#  0.40340909361839294,
#  0.34659090638160706,
#  0.39772728085517883,
#  0.3863636255264282,
#  0.3636363744735718,
#  0.3636363744735718,
#  0.3295454680919647,
#  0.3693181872367859,
#  0.34090909361839294,
#  0.39772728085517883,
#  0.4375,
#  0.3806818127632141,
#  0.3579545319080353,
#  0.34090909361839294,
#  0.4375,
#  0.4204545319080353,
#  0.3806818127632141]

# %%
history.history['val_acc']
# Out:
# [0.3375000059604645,
#  0.375,
#  0.36250001192092896,
#  0.32499998807907104,
#  0.2750000059604645,
#  0.20000000298023224,
#  0.30000001192092896,
#  0.375,
#  0.2874999940395355,
#  0.4124999940395355,
#  0.32499998807907104,
#  0.25,
#  0.23749999701976776,
#  0.375,
#  0.3125,
#  0.32499998807907104,
#  0.32499998807907104,
#  0.32499998807907104,
#  0.2874999940395355,
#  0.30000001192092896,
#  0.2750000059604645,
#  0.30000001192092896,
#  0.30000001192092896,
#  0.4124999940395355,
#  0.26249998807907104,
#  0.23749999701976776,
#  0.32499998807907104,
#  0.26249998807907104,
#  0.30000001192092896,
#  0.2874999940395355,
#  0.2874999940395355,
#  0.3375000059604645,
#  0.3375000059604645,
#  0.3499999940395355,
#  0.3375000059604645,
#  0.3499999940395355,
#  0.36250001192092896,
#  0.36250001192092896,
#  0.36250001192092896,
#  0.3499999940395355,
#  0.375,
#  0.36250001192092896,
#  0.3499999940395355,
#  0.3499999940395355,
#  0.3499999940395355,
#  0.3499999940395355,
#  0.3499999940395355,
#  0.36250001192092896,
#  0.3499999940395355,
#  0.38749998807907104]

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.show()
