# %% [markdown]
# <h1> Recherche </h1>

# %% [markdown]
# <h2>Etape 1 : générer des vidéos</h2>

# %%
# !pip install moviepy
# Out:
# Requirement already satisfied: moviepy in c:\users\minim\anaconda3\envs\python37\lib\site-packages (1.0.3)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in c:\users\minim\anaconda3\envs\python37\lib\site-packages (from moviepy) (4.51.0)
# Requirement already satisfied: requests<3.0,>=2.8.1 in c:\users\minim\anaconda3\envs\python37\lib\site-packages (from moviepy) (2.24.0)
# Requirement already satisfied: numpy>=1.17.3; python_version != "2.7" in c:\users\minim\appdata\roaming\python\python37\site-packages (from moviepy) (1.18.5)
# Requirement already satisfied: proglog<=1.0.0 in c:\users\minim\anaconda3\envs\python37\lib\site-packages (from moviepy) (0.1.9)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in c:\users\minim\anaconda3\envs\python37\lib\site-packages (from moviepy) (4.4.2)
# Requirement already satisfied: imageio-ffmpeg>=0.2.0; python_version >= "3.4" in c:\users\minim\anaconda3\envs\python37\lib\site-packages (from moviepy) (0.4.3)
# Requirement already satisfied: imageio<3.0,>=2.5; python_version >= "3.4" in c:\users\minim\anaconda3\envs\python37\lib\site-packages (from moviepy) (2.9.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\minim\anaconda3\envs\python37\lib\site-packages (from requests<3.0,>=2.8.1->moviepy) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\minim\anaconda3\envs\python37\lib\site-packages (from requests<3.0,>=2.8.1->moviepy) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\minim\anaconda3\envs\python37\lib\site-packages (from requests<3.0,>=2.8.1->moviepy) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\minim\anaconda3\envs\python37\lib\site-packages (from requests<3.0,>=2.8.1->moviepy) (2.10)
# Requirement already satisfied: pillow in c:\users\minim\anaconda3\envs\python37\lib\site-packages (from imageio<3.0,>=2.5; python_version >= "3.4"->moviepy) (8.1.0)

# %%
from moviepy.video.io.ffmpeg_tools import ffmpeg_extract_subclip
from moviepy.editor import VideoFileClip

def reshape_clip(name,num):
    clip = VideoFileClip(name)
    clip=clip.resize((360,360))
    clip.write_videofile(name.replace("#.mp4","@#.mp4"))
    print(clip.duration,"secondes")
    durée=clip.duration
    echelon=durée/num
    del clip
    for i in range(num):
        start_time,end_time=i*echelon,(i+1)*echelon
        ffmpeg_extract_subclip(name.replace("#.mp4","@#.mp4"), start_time, end_time, targetname=name.replace("#.mp4","{}.mp4".format(i)))
    return True
val=12
reshape_clip("./video/fache/fache#.mp4",val)
reshape_clip("./video/fache/maxou_fache#.mp4",val)
reshape_clip("./video/fache/antoju_fache#.mp4",val)
reshape_clip("./video/fache/theo_1#.mp4",val)
reshape_clip("./video/fache/theo_2#.mp4",val)
reshape_clip("./video/deg/theo_1#.mp4",val)
reshape_clip("./video/deg/theo_2#.mp4",val)
reshape_clip("./video/heureux/theo_1#.mp4",val)
#reshape_clip("./video/fache/s_fache#.mp4",8)
reshape_clip("./video/heureux/heureux#.mp4",val)
reshape_clip("./video/heureux/maxou_heureux#.mp4",val)
#
reshape_clip("./video/heureux/antoine_heureux#.mp4",val)
reshape_clip("./video/heureux/antoine2_heureux#.mp4",val)
reshape_clip("./video/heureux/antoju_heureux#.mp4",val)
reshape_clip("./video/triste/triste#.mp4",val)
reshape_clip("./video/triste/antoine_triste#.mp4",val)
reshape_clip("./video/triste/maxou_triste#.mp4",val)
reshape_clip("./video/deg/deg#.mp4",val)
reshape_clip("./video/deg/antoine_deg#.mp4",val)
reshape_clip("./video/deg/sound_deg#.mp4",val)
# Out:
# chunk:   0%|                                                                         | 0/306 [00:00<?, ?it/s, now=None]
# Moviepy - Building video ./video/fache/fache@#.mp4.
# MoviePy - Writing audio in fache@#TEMP_MPY_wvf_snd.mp3
# t:   0%|                                                                             | 0/107 [00:00<?, ?it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video ./video/fache/fache@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/fache/fache@#.mp4
# 13.84 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# chunk:   0%|                                                                         | 0/280 [00:00<?, ?it/s, now=None]
# Moviepy - Building video ./video/fache/maxou_fache@#.mp4.
# MoviePy - Writing audio in maxou_fache@#TEMP_MPY_wvf_snd.mp3
# t:   0%|                                                                              | 0/98 [00:00<?, ?it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video ./video/fache/maxou_fache@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/fache/maxou_fache@#.mp4
# 12.67 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# chunk:   0%|                                                                         | 0/411 [00:00<?, ?it/s, now=None]
# Moviepy - Building video ./video/fache/antoju_fache@#.mp4.
# MoviePy - Writing audio in antoju_fache@#TEMP_MPY_wvf_snd.mp3
# t:   0%|                                                                             | 0/540 [00:00<?, ?it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video ./video/fache/antoju_fache@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/fache/antoju_fache@#.mp4
# 18.6 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# t:   0%|                                                                              | 0/97 [00:00<?, ?it/s, now=None]
# Moviepy - Building video ./video/fache/theo_1@#.mp4.
# Moviepy - Writing video ./video/fache/theo_1@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/fache/theo_1@#.mp4
# 5.79 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# t:   0%|                                                                             | 0/110 [00:00<?, ?it/s, now=None]
# Moviepy - Building video ./video/fache/theo_2@#.mp4.
# Moviepy - Writing video ./video/fache/theo_2@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/fache/theo_2@#.mp4
# 6.56 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# t:   0%|                                                                             | 0/117 [00:00<?, ?it/s, now=None]
# Moviepy - Building video ./video/deg/theo_1@#.mp4.
# Moviepy - Writing video ./video/deg/theo_1@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/deg/theo_1@#.mp4
# 6.99 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# t:   0%|                                                                             | 0/115 [00:00<?, ?it/s, now=None]
# Moviepy - Building video ./video/deg/theo_2@#.mp4.
# Moviepy - Writing video ./video/deg/theo_2@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/deg/theo_2@#.mp4
# 6.87 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# t:   0%|                                                                             | 0/167 [00:00<?, ?it/s, now=None]
# Moviepy - Building video ./video/heureux/theo_1@#.mp4.
# Moviepy - Writing video ./video/heureux/theo_1@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/heureux/theo_1@#.mp4
# 10.0 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# chunk:   0%|                                                                         | 0/254 [00:00<?, ?it/s, now=None]
# Moviepy - Building video ./video/heureux/heureux@#.mp4.
# MoviePy - Writing audio in heureux@#TEMP_MPY_wvf_snd.mp3
# t:   0%|                                                                              | 0/89 [00:00<?, ?it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video ./video/heureux/heureux@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/heureux/heureux@#.mp4
# 11.49 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# chunk:   0%|                                                                         | 0/332 [00:00<?, ?it/s, now=None]
# Moviepy - Building video ./video/heureux/maxou_heureux@#.mp4.
# MoviePy - Writing audio in maxou_heureux@#TEMP_MPY_wvf_snd.mp3
# t:   0%|                                                                             | 0/116 [00:00<?, ?it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video ./video/heureux/maxou_heureux@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/heureux/maxou_heureux@#.mp4
# 15.03 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# chunk:   0%|                                                                         | 0/396 [00:00<?, ?it/s, now=None]
# Moviepy - Building video ./video/heureux/antoine_heureux@#.mp4.
# MoviePy - Writing audio in antoine_heureux@#TEMP_MPY_wvf_snd.mp3
# t:   0%|                                                                             | 0/520 [00:00<?, ?it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video ./video/heureux/antoine_heureux@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/heureux/antoine_heureux@#.mp4
# 17.93 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# chunk:   0%|                                                                         | 0/356 [00:00<?, ?it/s, now=None]
# Moviepy - Building video ./video/heureux/antoine2_heureux@#.mp4.
# MoviePy - Writing audio in antoine2_heureux@#TEMP_MPY_wvf_snd.mp3
# t:   0%|                                                                             | 0/469 [00:00<?, ?it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video ./video/heureux/antoine2_heureux@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/heureux/antoine2_heureux@#.mp4
# 16.14 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# chunk:   0%|                                                                         | 0/352 [00:00<?, ?it/s, now=None]
# Moviepy - Building video ./video/heureux/antoju_heureux@#.mp4.
# MoviePy - Writing audio in antoju_heureux@#TEMP_MPY_wvf_snd.mp3
# t:   0%|                                                                             | 0/462 [00:00<?, ?it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video ./video/heureux/antoju_heureux@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/heureux/antoju_heureux@#.mp4
# 15.93 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# chunk:   0%|                                                                         | 0/286 [00:00<?, ?it/s, now=None]
# Moviepy - Building video ./video/triste/triste@#.mp4.
# MoviePy - Writing audio in triste@#TEMP_MPY_wvf_snd.mp3
# t:   0%|                                                                             | 0/100 [00:00<?, ?it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video ./video/triste/triste@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/triste/triste@#.mp4
# 12.93 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# chunk:   0%|                                                                         | 0/384 [00:00<?, ?it/s, now=None]
# Moviepy - Building video ./video/triste/antoine_triste@#.mp4.
# MoviePy - Writing audio in antoine_triste@#TEMP_MPY_wvf_snd.mp3
# t:   0%|                                                                             | 0/504 [00:00<?, ?it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video ./video/triste/antoine_triste@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/triste/antoine_triste@#.mp4
# 17.37 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# chunk:   0%|                                                                         | 0/289 [00:00<?, ?it/s, now=None]
# Moviepy - Building video ./video/triste/maxou_triste@#.mp4.
# MoviePy - Writing audio in maxou_triste@#TEMP_MPY_wvf_snd.mp3
# t:   0%|                                                                             | 0/101 [00:00<?, ?it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video ./video/triste/maxou_triste@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/triste/maxou_triste@#.mp4
# 13.07 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# chunk:   0%|                                                                         | 0/277 [00:00<?, ?it/s, now=None]
# Moviepy - Building video ./video/deg/deg@#.mp4.
# MoviePy - Writing audio in deg@#TEMP_MPY_wvf_snd.mp3
# t:   0%|                                                                              | 0/97 [00:00<?, ?it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video ./video/deg/deg@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/deg/deg@#.mp4
# 12.55 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# chunk:   0%|                                                                         | 0/371 [00:00<?, ?it/s, now=None]
# Moviepy - Building video ./video/deg/antoine_deg@#.mp4.
# MoviePy - Writing audio in antoine_deg@#TEMP_MPY_wvf_snd.mp3
# t:   0%|                                                                             | 0/488 [00:00<?, ?it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video ./video/deg/antoine_deg@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/deg/antoine_deg@#.mp4
# 16.81 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# chunk:   0%|                                                                         | 0/226 [00:00<?, ?it/s, now=None]
# Moviepy - Building video ./video/deg/sound_deg@#.mp4.
# MoviePy - Writing audio in sound_deg@#TEMP_MPY_wvf_snd.mp3
# t:   0%|                                                                             | 0/297 [00:00<?, ?it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video ./video/deg/sound_deg@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/deg/sound_deg@#.mp4
# 10.22 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# True

# %%
reshape_clip("./video/deg/sound_deg#.mp4",val)
#reshape_clip("./video/heureux/sound_heureux#.mp4",val)
# Out:
# chunk:   0%|                                                                         | 0/226 [00:00<?, ?it/s, now=None]
# Moviepy - Building video ./video/deg/sound_deg@#.mp4.
# MoviePy - Writing audio in sound_deg@#TEMP_MPY_wvf_snd.mp3
# t:   0%|                                                                             | 0/297 [00:00<?, ?it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video ./video/deg/sound_deg@#.mp4
# Moviepy - Done !
# Moviepy - video ready ./video/deg/sound_deg@#.mp4
# 10.22 secondes
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# True

# %% [markdown]
# <h2>Etape 2 : extraire les vidéos pour créer le dataset</h2>

# %%
import os
import glob
import keras
from keras_video import VideoFrameGenerator
# use sub directories names as classes
classes = [i.split(os.path.sep)[1] for i in glob.glob('./video/*') if "#" not in i]
classes.sort()
# some global params
SIZE = (112, 112)
CHANNELS = 3
NBFRAME = 5
BS = 8
# pattern to get videos and classes
glob_pattern='./video/{classname}/*.mp4'
# for data augmentation
data_aug = keras.preprocessing.image.ImageDataGenerator(
    zoom_range=.1,
    horizontal_flip=True,
    rotation_range=8,
    width_shift_range=.2,
    height_shift_range=.2)
# Create video frame generator
train = VideoFrameGenerator(
    classes=classes, 
    glob_pattern=glob_pattern,
    nb_frames=NBFRAME,
    split=.33, 
    shuffle=True,
    batch_size=BS,
    target_shape=SIZE,
    nb_channel=CHANNELS,
    transformation=data_aug,
    use_frame_cache=True)
# Out:
# Warning, `split` argument is replaced by `split_val`, please condider to change your source code.The `split` argument will be removed in future releases.
# class deg, validation count: 23, train count: 47
# class fache, validation count: 23, train count: 47
# class heureux, validation count: 27, train count: 57
# class triste, validation count: 13, train count: 29
# Total data: 4 classes for 180 files for train

# %%
valid = train.get_validation_generator()
# Out:
# Total data: 4 classes for 86 files for validation

# %%
import keras_video.utils
keras_video.utils.show_sample(train)

# %% [markdown]
# <h2>Etape 3 : création du modèle</h2>

# %%
from keras.layers import Conv2D, BatchNormalization, \
    MaxPool2D, GlobalMaxPool2D, LSTM
def build_convnet(shape=(112, 112, 3)):
    momentum = .9
    model = keras.Sequential()
    model.add(Conv2D(64, (3,3), input_shape=shape,
        padding='same', activation='relu'))
    model.add(Conv2D(64, (3,3), padding='same', activation='relu'))
    model.add(BatchNormalization(momentum=momentum))
    
    model.add(MaxPool2D())
    
    model.add(Conv2D(128, (3,3), padding='same', activation='relu'))
    model.add(Conv2D(128, (3,3), padding='same', activation='relu'))
    model.add(BatchNormalization(momentum=momentum))
    
    model.add(MaxPool2D())
    
    model.add(Conv2D(256, (3,3), padding='same', activation='relu'))
    model.add(Conv2D(256, (3,3), padding='same', activation='relu'))
    model.add(BatchNormalization(momentum=momentum))
    
    # flatten...
    model.add(GlobalMaxPool2D())
    return model

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from keras.layers import TimeDistributed, GRU, Dense, Dropout
def action_model(shape=(5, 112, 112, 3), nbout=3):
    # Create our convnet with (112, 112, 3) input shape
    convnet = build_convnet(shape[1:])
    
    # then create our final model
    model = keras.Sequential()
    # add the convnet with (5, 112, 112, 3) shape
    model.add(TimeDistributed(convnet, input_shape=shape))
    # here, you can also use GRU or LSTM
    model.add(LSTM(64,dropout=0.2))
    # and finally, we make a decision network
    model.add(Dense(1024, activation='relu'))
    model.add(Dropout(.5))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(.5))
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(.5))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(nbout, activation='softmax'))
    return model

# %%
INSHAPE=(NBFRAME,) + SIZE + (CHANNELS,) # (5, 112, 112, 3)
model = action_model(INSHAPE, len(classes))
optimizer = keras.optimizers.Adam(0.001)
model.compile(
    optimizer,
    'categorical_crossentropy',
    metrics=['acc']
)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <h2>Etape 4 : Entraînement du modèle</h2>

# %%
EPOCHS=100
# create a "chkp" directory outside of the git repo before to run that
# because ModelCheckpoint will write models inside
callbacks = [
    keras.callbacks.ReduceLROnPlateau(verbose=1),
    keras.callbacks.ModelCheckpoint(
        './../chkp/weights.{epoch:02d}-{loss:.2f}.hdf5',
        verbose=1),
]
history=model.fit_generator(
    train,
    validation_data=valid,
    verbose=1,
    epochs=EPOCHS,
    callbacks=callbacks
)
# Out:
# WARNING:tensorflow:From <ipython-input-11-4bcf39e6f3a4>:15: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1
# Epoch 00063: saving model to ./../chkp\weights.63-1.12.hdf5
# 22/22 [==============================] - 145s 7s/step - loss: 1.1172 - acc: 0.4545 - val_loss: 1.1611 - val_acc: 0.4250
# Epoch 64/100
# 22/22 [==============================] - ETA: 0s - loss: 1.1767 - acc: 0.4148
# Epoch 00064: saving model to ./../chkp\weights.64-1.18.hdf5
# 22/22 [==============================] - 142s 6s/step - loss: 1.1767 - acc: 0.4148 - val_loss: 1.1528 - val_acc: 0.4375
# Epoch 65/100
# 22/22 [==============================] - ETA: 0s - loss: 1.1598 - acc: 0.4943
# Epoch 00065: saving model to ./../chkp\weights.65-1.16.hdf5
# 22/22 [==============================] - 145s 7s/step - loss: 1.1598 - acc: 0.4943 - val_loss: 1.1339 - val_acc: 0.4375
# Epoch 66/100
# 22/22 [==============================] - ETA: 0s - loss: 1.2161 - acc: 0.4375
# Epoch 00066: saving model to ./../chkp\weights.66-1.22.hdf5
# 22/22 [==============================] - 139s 6s/step - loss: 1.2161 - acc: 0.4375 - val_loss: 1.1418 - val_acc: 0.4125
# Epoch 67/100
# 22/22 [==============================] - ETA: 0s - loss: 1.1782 - acc: 0.4375
# Epoch 00067: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
#
# Epoch 00067: saving model to ./../chkp\weights.67-1.18.hdf5
# 22/22 [==============================] - 143s 6s/step - loss: 1.1782 - acc: 0.4375 - val_loss: 1.1600 - val_acc: 0.4250
# Epoch 68/100
# 22/22 [==============================] - ETA: 0s - loss: 1.2146 - acc: 0.4205
# Epoch 00068: saving model to ./../chkp\weights.68-1.21.hdf5
# 22/22 [==============================] - 146s 7s/step - loss: 1.2146 - acc: 0.4205 - val_loss: 1.1567 - val_acc: 0.4250
# Epoch 69/100
# 22/22 [==============================] - ETA: 0s - loss: 1.1543 - acc: 0.4432
# Epoch 00069: saving model to ./../chkp\weights.69-1.15.hdf5
# 22/22 [==============================] - 138s 6s/step - loss: 1.1543 - acc: 0.4432 - val_loss: 1.1680 - val_acc: 0.4250
# Epoch 70/100
# 22/22 [==============================] - ETA: 0s - loss: 1.2066 - acc: 0.4148
# Epoch 00070: saving model to ./../chkp\weights.70-1.21.hdf5
# 22/22 [==============================] - 141s 6s/step - loss: 1.2066 - acc: 0.4148 - val_loss: 1.1508 - val_acc: 0.4375
# Epoch 71/100
# 22/22 [==============================] - ETA: 0s - loss: 1.1415 - acc: 0.4659
# Epoch 00071: saving model to ./../chkp\weights.71-1.14.hdf5
# 22/22 [==============================] - 143s 6s/step - loss: 1.1415 - acc: 0.4659 - val_loss: 1.1544 - val_acc: 0.4500
# Epoch 72/100
# 22/22 [==============================] - ETA: 0s - loss: 1.1652 - acc: 0.4489
# Epoch 00072: saving model to ./../chkp\weights.72-1.17.hdf5
# 22/22 [==============================] - 143s 7s/step - loss: 1.1652 - acc: 0.4489 - val_loss: 1.1720 - val_acc: 0.4125
# Epoch 73/100
#  8/22 [=========>....................] - ETA: 1:18 - loss: 1.1818 - acc: 0.5156

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['acc'],label='acc')
plt.plot(history.history['val_acc'],label='val acc')
plt.xlabel("epoch")
plt.show()
